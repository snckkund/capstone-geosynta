# %% [markdown]
# # ROI: Madhya Pradesh
# ##  Export LST

# %%
import ee
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import calendar

# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project='ee-geosynta')

def get_mp_boundary():
    """Get Madhya Pradesh's administrative boundary"""
    states = ee.FeatureCollection('FAO/GAUL/2015/level1')
    mp = states.filter(ee.Filter.eq('ADM1_NAME', 'Madhya Pradesh')).geometry()
    return mp

def calculate_monthly_lst():
    """Calculate monthly LST averages for Madhya Pradesh"""
    modis_lst = ee.ImageCollection("MODIS/061/MOD11A2")
    roi = get_mp_boundary()

    current_year = datetime.now().year
    current_month = datetime.now().month

    monthly_data = []

    for year in range(2015, current_year + 1):
        for month in range(1, 13):
            if year == current_year and month > current_month:
                continue

            try:
                print(f"Processing monthly data for {calendar.month_name[month]} {year}...")

                monthly_collection = modis_lst.filter(ee.Filter.calendarRange(year, year, 'year')) \
                                            .filter(ee.Filter.calendarRange(month, month, 'month')) \
                                            .select('LST_Day_1km') \
                                            .map(lambda img: img.updateMask(img.gt(7500)))

                num_images = monthly_collection.size().getInfo()
                print(f"Number of images: {num_images}")

                if num_images == 0:
                    print(f"No data available")
                    continue

                monthly_mean = monthly_collection.mean()
                monthly_mean = monthly_mean.multiply(0.02).subtract(273.15)

                # Calculate additional statistics
                stats = monthly_mean.reduceRegion(
                    reducer=ee.Reducer.mean()
                            .combine(ee.Reducer.stdDev(), '', True)
                            .combine(ee.Reducer.minMax(), '', True),
                    geometry=roi,
                    scale=1000,
                    maxPixels=1e9
                ).getInfo()

                if 'LST_Day_1km_mean' in stats and stats['LST_Day_1km_mean'] is not None:
                    monthly_data.append({
                        'Year': year,
                        'Month': month,
                        'Month_Name': calendar.month_name[month],
                        'Mean_Temperature_Celsius': round(stats['LST_Day_1km_mean'], 2),
                        'Min_Temperature_Celsius': round(stats['LST_Day_1km_min'], 2),
                        'Max_Temperature_Celsius': round(stats['LST_Day_1km_max'], 2),
                        'StdDev_Temperature_Celsius': round(stats['LST_Day_1km_stdDev'], 2)
                    })
                    print(f"Processed: Mean={monthly_data[-1]['Mean_Temperature_Celsius']}°C, "
                          f"Min={monthly_data[-1]['Min_Temperature_Celsius']}°C, "
                          f"Max={monthly_data[-1]['Max_Temperature_Celsius']}°C")

            except Exception as e:
                print(f"Error processing {calendar.month_name[month]} {year}: {str(e)}")

    return pd.DataFrame(monthly_data)

def calculate_annual_lst():
    """Calculate annual LST averages for Madhya Pradesh"""
    modis_lst = ee.ImageCollection("MODIS/061/MOD11A2")
    roi = get_mp_boundary()

    current_year = datetime.now().year
    annual_data = []

    for year in range(2015, current_year + 1):
        try:
            print(f"Processing annual data for {year}...")

            yearly_collection = modis_lst.filter(ee.Filter.calendarRange(year, year, 'year')) \
                                       .select('LST_Day_1km') \
                                       .map(lambda img: img.updateMask(img.gt(7500)))

            if yearly_collection.size().getInfo() == 0:
                print(f"No data available")
                continue

            yearly_mean = yearly_collection.mean()
            yearly_mean = yearly_mean.multiply(0.02).subtract(273.15)

            # Calculate annual statistics
            stats = yearly_mean.reduceRegion(
                reducer=ee.Reducer.mean()
                        .combine(ee.Reducer.stdDev(), '', True)
                        .combine(ee.Reducer.minMax(), '', True),
                geometry=roi,
                scale=1000,
                maxPixels=1e9
            ).getInfo()

            if 'LST_Day_1km_mean' in stats and stats['LST_Day_1km_mean'] is not None:
                annual_data.append({
                    'Year': year,
                    'Mean_Temperature_Celsius': round(stats['LST_Day_1km_mean'], 2),
                    'Min_Temperature_Celsius': round(stats['LST_Day_1km_min'], 2),
                    'Max_Temperature_Celsius': round(stats['LST_Day_1km_max'], 2),
                    'StdDev_Temperature_Celsius': round(stats['LST_Day_1km_stdDev'], 2)
                })
                print(f"Processed: Mean={annual_data[-1]['Mean_Temperature_Celsius']}°C")

        except Exception as e:
            print(f"Error processing {year}: {str(e)}")

    return pd.DataFrame(annual_data)

def export_data():
    """Export both monthly and annual LST data for Madhya Pradesh"""
    try:
        # Calculate and export monthly data
        print("\nProcessing monthly averages...")
        monthly_df = calculate_monthly_lst()
        monthly_output = 'mp_monthly_lst_data.csv'
        monthly_df.to_csv(monthly_output, index=False)
        print(f"Monthly data exported to {monthly_output}")
        print("\nMonthly data sample:")
        print(monthly_df.head())

        # Calculate and export annual data
        print("\nProcessing annual averages...")
        annual_df = calculate_annual_lst()
        annual_output = 'mp_annual_lst_data.csv'
        annual_df.to_csv(annual_output, index=False)
        print(f"Annual data exported to {annual_output}")
        print("\nAnnual data:")
        print(annual_df)

        # Generate summary statistics
        print("\nMonthly Summary Statistics:")
        monthly_stats = monthly_df.groupby('Month_Name')['Mean_Temperature_Celsius'].agg(['mean', 'min', 'max', 'std']).round(2)
        print(monthly_stats)

        print("\nAnnual Summary Statistics:")
        annual_stats = annual_df['Mean_Temperature_Celsius'].agg(['mean', 'min', 'max', 'std']).round(2)
        print(annual_stats)

    except Exception as e:
        print(f"An error occurred: {str(e)}")
        print("Please check:")
        print("1. Earth Engine authentication is valid")
        print("2. Internet connection is stable")
        print("3. The specified region has available data")

if __name__ == "__main__":
    export_data()
# Out:
# Processing monthly averages...
# Processing monthly data for January 2015...
# Number of images: 4
# Processed: Mean=23.08°C, Min=14.61°C, Max=34.28°C
# Processing monthly data for February 2015...
# Number of images: 4
# Processed: Mean=29.23°C, Min=19.51°C, Max=41.5°C
# Processing monthly data for March 2015...
# Number of images: 4
# Processed: Mean=36.27°C, Min=22.84°C, Max=47.17°C
# Processing monthly data for April 2015...
# Number of images: 3
# Processed: Mean=41.25°C, Min=25.08°C, Max=50.12°C
# Processing monthly data for May 2015...
# Number of images: 4
# Processed: Mean=46.0°C, Min=27.49°C, Max=53.25°C
# Processing monthly data for June 2015...
# Number of images: 4
# Processed: Mean=40.56°C, Min=23.91°C, Max=54.03°C
# Processing monthly data for July 2015...
# Number of images: 4
# Processed: Mean=33.56°C, Min=10.69°C, Max=47.19°C
# Processing monthly data for August 2015...
# Number of images: 4
# Processed: Mean=30.23°C, Min=16.93°C, Max=41.57°C
# Processing monthly data for September 2015...
# Number of images: 4
# Processed: Mean=34.15°C, Min=24.04°C, Max=42.96°C
# Processing monthly data for October 2015...
# Number of images: 3
# Processed: Mean=35.87°C, Min=25.88°C, Max=43.72°C
# Processing monthly data for November 2015...
# Number of images: 4
# Processed: Mean=32.33°C, Min=23.28°C, Max=40.32°C
# Processing monthly data for December 2015...
# Number of images: 4
# Processed: Mean=27.34°C, Min=19.62°C, Max=37.16°C
# Processing monthly data for January 2016...
# Number of images: 4
# Processed: Mean=26.93°C, Min=18.48°C, Max=36.97°C
# Processing monthly data for February 2016...
# Number of images: 4
# Processed: Mean=31.97°C, Min=20.13°C, Max=42.63°C
# Processing monthly data for March 2016...
# Number of images: 4
# Processed: Mean=40.3°C, Min=23.83°C, Max=49.55°C
# Processing monthly data for April 2016...
# Number of images: 4
# Processed: Mean=47.46°C, Min=26.99°C, Max=54.31°C
# Processing monthly data for May 2016...
# Number of images: 3
# Processed: Mean=45.17°C, Min=27.11°C, Max=52.53°C
# Processing monthly data for June 2016...
# Number of images: 4
# Processed: Mean=41.68°C, Min=18.09°C, Max=52.63°C
# Processing monthly data for July 2016...
# Number of images: 4
# Processed: Mean=31.47°C, Min=8.29°C, Max=43.23°C
# Processing monthly data for August 2016...
# Number of images: 4
# Processed: Mean=28.55°C, Min=-12.53°C, Max=39.47°C
# Processing monthly data for September 2016...
# Number of images: 4
# Processed: Mean=30.83°C, Min=16.15°C, Max=40.27°C
# Processing monthly data for October 2016...
# Number of images: 4
# Processed: Mean=32.84°C, Min=23.81°C, Max=41.16°C
# Processing monthly data for November 2016...
# Number of images: 3
# Processed: Mean=31.3°C, Min=22.63°C, Max=39.74°C
# Processing monthly data for December 2016...
# Number of images: 4
# Processed: Mean=27.15°C, Min=20.08°C, Max=36.37°C
# Processing monthly data for January 2017...
# Number of images: 4
# Processed: Mean=25.08°C, Min=17.99°C, Max=34.65°C
# Processing monthly data for February 2017...
# Number of images: 4
# Processed: Mean=30.99°C, Min=20.33°C, Max=41.41°C
# Processing monthly data for March 2017...
# Number of images: 4
# Processed: Mean=40.23°C, Min=24.12°C, Max=48.32°C
# Processing monthly data for April 2017...
# Number of images: 3
# Processed: Mean=46.81°C, Min=26.3°C, Max=52.84°C
# Processing monthly data for May 2017...
# Number of images: 4
# Processed: Mean=46.27°C, Min=27.03°C, Max=52.63°C
# Processing monthly data for June 2017...
# Number of images: 4
# Processed: Mean=41.17°C, Min=25.29°C, Max=57.53°C
# Processing monthly data for July 2017...
# Number of images: 4
# Processed: Mean=33.61°C, Min=5.65°C, Max=46.29°C
# Processing monthly data for August 2017...
# Number of images: 4
# Processed: Mean=29.46°C, Min=-14.39°C, Max=42.68°C
# Processing monthly data for September 2017...
# Number of images: 4
# Processed: Mean=32.72°C, Min=22.68°C, Max=41.89°C
# Processing monthly data for October 2017...
# Number of images: 3
# Processed: Mean=34.78°C, Min=24.68°C, Max=43.04°C
# Processing monthly data for November 2017...
# Number of images: 4
# Processed: Mean=30.94°C, Min=22.37°C, Max=38.37°C
# Processing monthly data for December 2017...
# Number of images: 4
# Processed: Mean=26.42°C, Min=18.82°C, Max=34.73°C
# Processing monthly data for January 2018...
# Number of images: 4
# Processed: Mean=26.73°C, Min=18.81°C, Max=36.33°C
# Processing monthly data for February 2018...
# Number of images: 4
# Processed: Mean=31.51°C, Min=20.43°C, Max=40.73°C
# Processing monthly data for March 2018...
# Number of images: 4
# Processed: Mean=41.33°C, Min=24.26°C, Max=48.4°C
# Processing monthly data for April 2018...
# Number of images: 3
# Processed: Mean=44.93°C, Min=26.5°C, Max=52.13°C
# Processing monthly data for May 2018...
# Number of images: 4
# Processed: Mean=45.42°C, Min=26.63°C, Max=51.97°C
# Processing monthly data for June 2018...
# Number of images: 4
# Processed: Mean=39.92°C, Min=23.44°C, Max=51.52°C
# Processing monthly data for July 2018...
# Number of images: 4
# Processed: Mean=35.42°C, Min=5.31°C, Max=48.59°C
# Processing monthly data for August 2018...
# Number of images: 4
# Processed: Mean=28.29°C, Min=-6.17°C, Max=43.01°C
# Processing monthly data for September 2018...
# Number of images: 4
# Processed: Mean=32.16°C, Min=23.06°C, Max=42.56°C
# Processing monthly data for October 2018...
# Number of images: 3
# Processed: Mean=35.01°C, Min=25.1°C, Max=43.24°C
# Processing monthly data for November 2018...
# Number of images: 4
# Processed: Mean=31.58°C, Min=23.18°C, Max=39.6°C
# Processing monthly data for December 2018...
# Number of images: 4
# Processed: Mean=25.39°C, Min=18.59°C, Max=34.59°C
# Processing monthly data for January 2019...
# Number of images: 4
# Processed: Mean=24.78°C, Min=17.23°C, Max=34.55°C
# Processing monthly data for February 2019...
# Number of images: 4
# Processed: Mean=28.8°C, Min=18.63°C, Max=39.47°C
# Processing monthly data for March 2019...
# Number of images: 4
# Processed: Mean=39.12°C, Min=23.31°C, Max=48.8°C
# Processing monthly data for April 2019...
# Number of images: 3
# Processed: Mean=46.52°C, Min=27.28°C, Max=54.58°C
# Processing monthly data for May 2019...
# Number of images: 4
# Processed: Mean=47.9°C, Min=28.68°C, Max=54.06°C
# Processing monthly data for June 2019...
# Number of images: 4
# Processed: Mean=43.97°C, Min=25.98°C, Max=52.52°C
# Processing monthly data for July 2019...
# Number of images: 4
# Processed: Mean=35.9°C, Min=17.71°C, Max=47.67°C
# Processing monthly data for August 2019...
# Number of images: 4
# Processed: Mean=28.1°C, Min=-2.65°C, Max=41.33°C
# Processing monthly data for September 2019...
# Number of images: 4
# Processed: Mean=28.98°C, Min=3.5°C, Max=36.95°C
# Processing monthly data for October 2019...
# Number of images: 3
# Processed: Mean=31.35°C, Min=21.37°C, Max=38.83°C
# Processing monthly data for November 2019...
# Number of images: 4
# Processed: Mean=30.25°C, Min=22.96°C, Max=37.14°C
# Processing monthly data for December 2019...
# Number of images: 4
# Processed: Mean=23.87°C, Min=15.36°C, Max=32.65°C
# Processing monthly data for January 2020...
# Number of images: 4
# Processed: Mean=22.73°C, Min=16.84°C, Max=32.95°C
# Processing monthly data for February 2020...
# Number of images: 4
# Processed: Mean=27.45°C, Min=18.27°C, Max=38.56°C
# Processing monthly data for March 2020...
# Number of images: 4
# Processed: Mean=35.06°C, Min=21.85°C, Max=45.75°C
# Processing monthly data for April 2020...
# Number of images: 4
# Processed: Mean=43.99°C, Min=26.12°C, Max=51.94°C
# Processing monthly data for May 2020...
# Number of images: 3
# Processed: Mean=45.99°C, Min=27.81°C, Max=54.16°C
# Processing monthly data for June 2020...
# Number of images: 4
# Processed: Mean=36.86°C, Min=16.07°C, Max=50.33°C
# Processing monthly data for July 2020...
# Number of images: 4
# Processed: Mean=32.8°C, Min=-0.95°C, Max=49.04°C
# Processing monthly data for August 2020...
# Number of images: 4
# Processed: Mean=29.12°C, Min=-11.19°C, Max=42.85°C
# Processing monthly data for September 2020...
# Number of images: 4
# Processed: Mean=32.08°C, Min=21.34°C, Max=42.33°C
# Processing monthly data for October 2020...
# Number of images: 4
# Processed: Mean=33.7°C, Min=22.13°C, Max=42.1°C
# Processing monthly data for November 2020...
# Number of images: 3
# Processed: Mean=29.85°C, Min=22.08°C, Max=37.74°C
# Processing monthly data for December 2020...
# Number of images: 4
# Processed: Mean=26.23°C, Min=19.5°C, Max=33.69°C
# Processing monthly data for January 2021...
# Number of images: 4
# Processed: Mean=25.46°C, Min=17.65°C, Max=34.81°C
# Processing monthly data for February 2021...
# Number of images: 4
# Processed: Mean=31.16°C, Min=19.94°C, Max=40.89°C
# Processing monthly data for March 2021...
# Number of images: 4
# Processed: Mean=39.6°C, Min=24.17°C, Max=48.48°C
# Processing monthly data for April 2021...
# Number of images: 3
# Processed: Mean=44.62°C, Min=25.61°C, Max=51.66°C
# Processing monthly data for May 2021...
# Number of images: 4
# Processed: Mean=42.53°C, Min=26.08°C, Max=51.39°C
# Processing monthly data for June 2021...
# Number of images: 4
# Processed: Mean=36.88°C, Min=15.43°C, Max=54.71°C
# Processing monthly data for July 2021...
# Number of images: 4
# Processed: Mean=37.95°C, Min=20.55°C, Max=52.11°C
# Processing monthly data for August 2021...
# Number of images: 4
# Processed: Mean=30.12°C, Min=-1.37°C, Max=44.33°C
# Processing monthly data for September 2021...
# Number of images: 4
# Processed: Mean=30.34°C, Min=10.44°C, Max=42.47°C
# Processing monthly data for October 2021...
# Number of images: 3
# Processed: Mean=31.87°C, Min=24.2°C, Max=40.4°C
# Processing monthly data for November 2021...
# Number of images: 4
# Processed: Mean=29.67°C, Min=22.32°C, Max=35.77°C
# Processing monthly data for December 2021...
# Number of images: 4
# Processed: Mean=24.46°C, Min=17.07°C, Max=31.04°C
# Processing monthly data for January 2022...
# Number of images: 4
# Processed: Mean=22.13°C, Min=15.89°C, Max=31.81°C
# Processing monthly data for February 2022...
# Number of images: 4
# Processed: Mean=27.93°C, Min=19.22°C, Max=39.14°C
# Processing monthly data for March 2022...
# Number of images: 4
# Processed: Mean=39.76°C, Min=24.97°C, Max=49.47°C
# Processing monthly data for April 2022...
# Number of images: 3
# Processed: Mean=45.43°C, Min=27.14°C, Max=52.29°C
# Processing monthly data for May 2022...
# Number of images: 4
# Processed: Mean=42.68°C, Min=26.16°C, Max=48.92°C
# Processing monthly data for June 2022...
# Number of images: 4
# Processed: Mean=41.36°C, Min=25.91°C, Max=50.59°C
# Processing monthly data for July 2022...
# Number of images: 4
# Processed: Mean=33.17°C, Min=-4.63°C, Max=45.75°C
# Processing monthly data for August 2022...
# Number of images: 4
# Processed: Mean=28.99°C, Min=4.81°C, Max=42.17°C
# Processing monthly data for September 2022...
# Number of images: 4
# Processed: Mean=30.32°C, Min=21.34°C, Max=38.82°C
# Processing monthly data for October 2022...
# Number of images: 3
# Processed: Mean=31.52°C, Min=19.78°C, Max=39.83°C
# Processing monthly data for November 2022...
# Number of images: 4
# Processed: Mean=29.32°C, Min=21.55°C, Max=37.14°C
# Processing monthly data for December 2022...
# Number of images: 4
# Processed: Mean=25.26°C, Min=19.28°C, Max=33.54°C
# Processing monthly data for January 2023...
# Number of images: 4
# Processed: Mean=22.87°C, Min=15.44°C, Max=32.0°C
# Processing monthly data for February 2023...
# Number of images: 4
# Processed: Mean=29.56°C, Min=20.79°C, Max=40.79°C
# Processing monthly data for March 2023...
# Number of images: 4
# Processed: Mean=35.39°C, Min=22.8°C, Max=44.17°C
# Processing monthly data for April 2023...
# Number of images: 3
# Processed: Mean=41.85°C, Min=25.04°C, Max=50.33°C
# Processing monthly data for May 2023...
# Number of images: 4
# Processed: Mean=42.55°C, Min=26.76°C, Max=49.94°C
# Processing monthly data for June 2023...
# Number of images: 4
# Processed: Mean=42.05°C, Min=25.21°C, Max=50.39°C
# Processing monthly data for July 2023...
# Number of images: 4
# Processed: Mean=32.62°C, Min=5.79°C, Max=45.77°C
# Processing monthly data for August 2023...
# Number of images: 4
# Processed: Mean=29.55°C, Min=18.28°C, Max=40.4°C
# Processing monthly data for September 2023...
# Number of images: 4
# Processed: Mean=30.43°C, Min=21.24°C, Max=39.97°C
# Processing monthly data for October 2023...
# Number of images: 3
# Processed: Mean=32.86°C, Min=25.0°C, Max=40.67°C
# Processing monthly data for November 2023...
# Number of images: 4
# Processed: Mean=29.16°C, Min=22.79°C, Max=35.94°C
# Processing monthly data for December 2023...
# Number of images: 4
# Processed: Mean=23.32°C, Min=16.27°C, Max=30.35°C
# Processing monthly data for January 2024...
# Number of images: 4
# Processed: Mean=21.97°C, Min=13.47°C, Max=30.64°C
# Processing monthly data for February 2024...
# Number of images: 4
# Processed: Mean=26.58°C, Min=18.03°C, Max=35.3°C
# Processing monthly data for March 2024...
# Number of images: 4
# Processed: Mean=35.56°C, Min=22.77°C, Max=44.42°C
# Processing monthly data for April 2024...
# Number of images: 4
# Processed: Mean=42.15°C, Min=26.46°C, Max=50.48°C
# Processing monthly data for May 2024...
# Number of images: 3
# Processed: Mean=41.09°C, Min=26.78°C, Max=53.7°C
# Processing monthly data for June 2024...
# Number of images: 4
# Processed: Mean=40.34°C, Min=26.08°C, Max=51.87°C
# Processing monthly data for July 2024...
# Number of images: 4
# Processed: Mean=31.86°C, Min=2.47°C, Max=43.29°C
# Processing monthly data for August 2024...
# Number of images: 4
# Processed: Mean=27.68°C, Min=-1.15°C, Max=36.47°C
# Processing monthly data for September 2024...
# Number of images: 4
# Processed: Mean=28.98°C, Min=15.4°C, Max=36.45°C
# Processing monthly data for October 2024...
# Number of images: 4
# Processed: Mean=30.98°C, Min=22.3°C, Max=37.6°C
# Processing monthly data for November 2024...
# Number of images: 3
# Processed: Mean=27.23°C, Min=20.02°C, Max=32.6°C
# Processing monthly data for December 2024...
# Number of images: 3
# Processed: Mean=23.04°C, Min=17.42°C, Max=30.26°C
# Processing monthly data for January 2025...
# Number of images: 0
# No data available
# Monthly data exported to mp_monthly_lst_data.csv
#
# Monthly data sample:
#    Year  Month Month_Name  Mean_Temperature_Celsius  Min_Temperature_Celsius  \
# 0  2015      1    January                     23.08                    14.61
# 1  2015      2   February                     29.23                    19.51
# 2  2015      3      March                     36.27                    22.84
# 3  2015      4      April                     41.25                    25.08
# 4  2015      5        May                     46.00                    27.49
#
#    Max_Temperature_Celsius  StdDev_Temperature_Celsius
# 0                    34.28                        2.88
# 1                    41.50                        3.34
# 2                    47.17                        3.45
# 3                    50.12                        3.29
# 4                    53.25                        3.19
#
# Processing annual averages...
# Processing annual data for 2015...
# Processed: Mean=34.1°C
# Processing annual data for 2016...
# Processed: Mean=35.24°C
# Processing annual data for 2017...
# Processed: Mean=34.96°C
# Processing annual data for 2018...
# Processed: Mean=35.04°C
# Processing annual data for 2019...
# Processed: Mean=34.55°C
# Processing annual data for 2020...
# Processed: Mean=33.02°C
# Processing annual data for 2021...
# Processed: Mean=33.71°C
# Processing annual data for 2022...
# Processed: Mean=33.14°C
# Processing annual data for 2023...
# Processed: Mean=32.37°C
# Processing annual data for 2024...
# Processed: Mean=31.93°C
# Processing annual data for 2025...
# No data available
# Annual data exported to mp_annual_lst_data.csv
#
# Annual data:
#    Year  Mean_Temperature_Celsius  Min_Temperature_Celsius  \
# 0  2015                     34.10                    23.71
# 1  2016                     35.24                    24.19
# 2  2017                     34.96                    23.98
# 3  2018                     35.04                    23.87
# 4  2019                     34.55                    24.38
# 5  2020                     33.02                    23.77
# 6  2021                     33.71                    23.60
# 7  2022                     33.14                    23.70
# 8  2023                     32.37                    23.45
# 9  2024                     31.93                    23.51
#
#    Max_Temperature_Celsius  StdDev_Temperature_Celsius
# 0                    41.08                        2.23
# 1                    41.18                        2.08
# 2                    41.13                        1.88
# 3                    41.60                        2.14
# 4                    40.94                        1.99
# 5                    40.06                        2.16
# 6                    40.19                        2.07
# 7                    39.70                        1.86
# 8                    38.83                        1.83
# 9                    37.33                        1.75
#
# Monthly Summary Statistics:
#              mean    min    max   std
# Month_Name
# April       44.50  41.25  47.46  2.18
# August      29.01  27.68  30.23  0.85
# December    25.25  23.04  27.34  1.54
# February    29.52  26.58  31.97  1.85
# January     24.18  21.97  26.93  1.86
# July        33.84  31.47  37.95  2.01
# June        40.48  36.86  43.97  2.20
# March       38.26  35.06  41.33  2.40
# May         44.56  41.09  47.90  2.19
# November    30.16  27.23  32.33  1.46
# October     33.08  30.98  35.87  1.71
# September   31.10  28.98  34.15  1.66
#
# Annual Summary Statistics:
# mean    33.81
# min     31.93
# max     35.24
# std      1.16
# Name: Mean_Temperature_Celsius, dtype: float64

# %% [markdown]
# ## Export Humidity

# %%
import ee
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import calendar

# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project='ee-geosynta')

def get_mp_boundary():
    """Get Madhya Pradesh's administrative boundary"""
    states = ee.FeatureCollection('FAO/GAUL/2015/level1')
    mp = states.filter(ee.Filter.eq('ADM1_NAME', 'Madhya Pradesh')).geometry()
    return mp

def calculate_relative_humidity(T, p, q):
    """
    Calculate relative humidity using specific humidity, pressure, and temperature.
    Based on the August-Roche-Magnus approximation.

    Args:
        T: Temperature in Kelvin
        p: Surface pressure in Pa
        q: Specific humidity in kg/kg
    Returns:
        Relative humidity (0-1)
    """
    # Convert temperature to Celsius
    T_C = T.subtract(273.15)

    # Calculate saturation vapor pressure (hPa)
    es = ee.Image(6.112).multiply(ee.Image.exp(ee.Image(17.67).multiply(T_C).divide(T_C.add(243.5))))

    # Convert pressure from Pa to hPa
    p_hPa = p.divide(100)

    # Calculate vapor pressure from specific humidity
    e = q.multiply(p_hPa).divide(ee.Image(0.622).add(q.multiply(ee.Image(0.378))))

    # Calculate relative humidity (0-1)
    rh = e.divide(es)

    # Ensure values are between 0 and 1
    rh = rh.max(ee.Image(0)).min(ee.Image(1))

    return rh

def calculate_monthly_humidity():
    """Calculate monthly humidity averages for Madhya Pradesh"""
    gldas = ee.ImageCollection("NASA/GLDAS/V021/NOAH/G025/T3H")
    roi = get_mp_boundary()

    current_year = datetime.now().year
    current_month = datetime.now().month

    monthly_data = []

    for year in range(2015, current_year + 1):
        for month in range(1, 13):
            if year == current_year and month > current_month:
                continue

            try:
                print(f"Processing monthly data for {calendar.month_name[month]} {year}...")

                monthly_collection = gldas.filter(ee.Filter.calendarRange(year, year, 'year')) \
                                       .filter(ee.Filter.calendarRange(month, month, 'month')) \
                                       .select(['Tair_f_inst', 'Psurf_f_inst', 'Qair_f_inst'])

                num_images = monthly_collection.size().getInfo()
                print(f"Number of images: {num_images}")

                if num_images == 0:
                    print(f"No data available")
                    continue

                # Calculate means for each parameter
                T = monthly_collection.select('Tair_f_inst').mean()
                p = monthly_collection.select('Psurf_f_inst').mean()
                q = monthly_collection.select('Qair_f_inst').mean()

                # Calculate relative humidity
                rh = calculate_relative_humidity(T, p, q)

                # Combine all bands for statistics
                combined = T.addBands(p).addBands(q).addBands(rh.rename('RH'))

                stats = combined.reduceRegion(
                    reducer=ee.Reducer.mean()
                            .combine(ee.Reducer.stdDev(), '', True)
                            .combine(ee.Reducer.minMax(), '', True),
                    geometry=roi,
                    scale=25000,
                    maxPixels=1e9
                ).getInfo()

                if stats['Tair_f_inst_mean'] is not None:
                    monthly_data.append({
                        'Year': year,
                        'Month': month,
                        'Month_Name': calendar.month_name[month],
                        'Temperature_K': round(stats['Tair_f_inst_mean'], 2),
                        'Temperature_C': round(stats['Tair_f_inst_mean'] - 273.15, 2),
                        'Pressure_Pa': round(stats['Psurf_f_inst_mean'], 2),
                        'Specific_Humidity': round(stats['Qair_f_inst_mean'], 4),
                        'Relative_Humidity': round(stats['RH_mean'] * 100, 2),  # Convert to percentage
                        'Temperature_StdDev': round(stats['Tair_f_inst_stdDev'], 2),
                        'Pressure_StdDev': round(stats['Psurf_f_inst_stdDev'], 2),
                        'Specific_Humidity_StdDev': round(stats['Qair_f_inst_stdDev'], 4)
                    })
                    print(f"Processed: Temp={monthly_data[-1]['Temperature_C']}°C, RH={monthly_data[-1]['Relative_Humidity']}%")

            except Exception as e:
                print(f"Error processing {calendar.month_name[month]} {year}: {str(e)}")

    return pd.DataFrame(monthly_data)

def calculate_annual_humidity():
    """Calculate annual humidity averages for Madhya Pradesh"""
    gldas = ee.ImageCollection("NASA/GLDAS/V021/NOAH/G025/T3H")
    roi = get_mp_boundary()

    current_year = datetime.now().year
    annual_data = []

    for year in range(2015, current_year + 1):
        try:
            print(f"Processing annual data for {year}...")

            yearly_collection = gldas.filter(ee.Filter.calendarRange(year, year, 'year')) \
                                   .select(['Tair_f_inst', 'Psurf_f_inst', 'Qair_f_inst'])

            if yearly_collection.size().getInfo() == 0:
                print(f"No data available")
                continue

            # Calculate means for each parameter
            T = yearly_collection.select('Tair_f_inst').mean()
            p = yearly_collection.select('Psurf_f_inst').mean()
            q = yearly_collection.select('Qair_f_inst').mean()

            # Calculate relative humidity
            rh = calculate_relative_humidity(T, p, q)

            # Combine all bands for statistics
            combined = T.addBands(p).addBands(q).addBands(rh.rename('RH'))

            stats = combined.reduceRegion(
                reducer=ee.Reducer.mean()
                        .combine(ee.Reducer.stdDev(), '', True)
                        .combine(ee.Reducer.minMax(), '', True),
                geometry=roi,
                scale=25000,
                maxPixels=1e9
            ).getInfo()

            if stats['Tair_f_inst_mean'] is not None:
                annual_data.append({
                    'Year': year,
                    'Temperature_K': round(stats['Tair_f_inst_mean'], 2),
                    'Temperature_C': round(stats['Tair_f_inst_mean'] - 273.15, 2),
                    'Pressure_Pa': round(stats['Psurf_f_inst_mean'], 2),
                    'Specific_Humidity': round(stats['Qair_f_inst_mean'], 4),
                    'Relative_Humidity': round(stats['RH_mean'] * 100, 2),  # Convert to percentage
                    'Temperature_StdDev': round(stats['Tair_f_inst_stdDev'], 2),
                    'Pressure_StdDev': round(stats['Psurf_f_inst_stdDev'], 2),
                    'Specific_Humidity_StdDev': round(stats['Qair_f_inst_stdDev'], 4)
                })
                print(f"Processed: Temp={annual_data[-1]['Temperature_C']}°C, RH={annual_data[-1]['Relative_Humidity']}%")

        except Exception as e:
            print(f"Error processing {year}: {str(e)}")

    return pd.DataFrame(annual_data)

def export_humidity_data():
    """Export both monthly and annual humidity data for Madhya Pradesh"""
    try:
        # Calculate and export monthly data
        print("\nProcessing monthly averages...")
        monthly_df = calculate_monthly_humidity()
        monthly_output = 'mp_monthly_humidity_data.csv'
        monthly_df.to_csv(monthly_output, index=False)
        print(f"Monthly data exported to {monthly_output}")
        print("\nMonthly data sample:")
        print(monthly_df.head())

        # Calculate and export annual data
        print("\nProcessing annual averages...")
        annual_df = calculate_annual_humidity()
        annual_output = 'mp_annual_humidity_data.csv'
        annual_df.to_csv(annual_output, index=False)
        print(f"Annual data exported to {annual_output}")
        print("\nAnnual data:")
        print(annual_df)

        # Generate summary statistics
        print("\nMonthly Summary Statistics:")
        monthly_stats = monthly_df.groupby('Month_Name')['Relative_Humidity'].agg(['mean', 'min', 'max', 'std']).round(2)
        print(monthly_stats)

        print("\nAnnual Summary Statistics:")
        annual_stats = annual_df['Relative_Humidity'].agg(['mean', 'min', 'max', 'std']).round(2)
        print(annual_stats)

    except Exception as e:
        print(f"An error occurred: {str(e)}")
        print("Please check:")
        print("1. Earth Engine authentication is valid")
        print("2. Internet connection is stable")
        print("3. The specified region has available data")

if __name__ == "__main__":
    export_humidity_data()
# Out:
# Processing monthly averages...
# Processing monthly data for January 2015...
# Number of images: 248
# Processed: Temp=16.24°C, RH=51.55%
# Processing monthly data for February 2015...
# Number of images: 224
# Processed: Temp=21.97°C, RH=35.18%
# Processing monthly data for March 2015...
# Number of images: 248
# Processed: Temp=25.2°C, RH=33.94%
# Processing monthly data for April 2015...
# Number of images: 240
# Processed: Temp=31.06°C, RH=24.59%
# Processing monthly data for May 2015...
# Number of images: 248
# Processed: Temp=35.82°C, RH=18.49%
# Processing monthly data for June 2015...
# Number of images: 240
# Processed: Temp=32.77°C, RH=43.2%
# Processing monthly data for July 2015...
# Number of images: 248
# Processed: Temp=28.29°C, RH=68.51%
# Processing monthly data for August 2015...
# Number of images: 248
# Processed: Temp=27.28°C, RH=75.12%
# Processing monthly data for September 2015...
# Number of images: 240
# Processed: Temp=27.58°C, RH=60.53%
# Processing monthly data for October 2015...
# Number of images: 248
# Processed: Temp=26.69°C, RH=41.92%
# Processing monthly data for November 2015...
# Number of images: 240
# Processed: Temp=23.8°C, RH=42.63%
# Processing monthly data for December 2015...
# Number of images: 248
# Processed: Temp=18.81°C, RH=38.08%
# Processing monthly data for January 2016...
# Number of images: 248
# Processed: Temp=18.68°C, RH=41.35%
# Processing monthly data for February 2016...
# Number of images: 232
# Processed: Temp=22.84°C, RH=31.38%
# Processing monthly data for March 2016...
# Number of images: 248
# Processed: Temp=28.22°C, RH=24.92%
# Processing monthly data for April 2016...
# Number of images: 240
# Processed: Temp=33.49°C, RH=16.04%
# Processing monthly data for May 2016...
# Number of images: 248
# Processed: Temp=35.39°C, RH=23.34%
# Processing monthly data for June 2016...
# Number of images: 240
# Processed: Temp=33.94°C, RH=40.71%
# Processing monthly data for July 2016...
# Number of images: 248
# Processed: Temp=27.66°C, RH=77.36%
# Processing monthly data for August 2016...
# Number of images: 248
# Processed: Temp=25.8°C, RH=85.43%
# Processing monthly data for September 2016...
# Number of images: 240
# Processed: Temp=26.59°C, RH=77.33%
# Processing monthly data for October 2016...
# Number of images: 248
# Processed: Temp=24.69°C, RH=55.91%
# Processing monthly data for November 2016...
# Number of images: 240
# Processed: Temp=20.74°C, RH=35.13%
# Processing monthly data for December 2016...
# Number of images: 248
# Processed: Temp=17.78°C, RH=40.11%
# Processing monthly data for January 2017...
# Number of images: 248
# Processed: Temp=17.69°C, RH=45.72%
# Processing monthly data for February 2017...
# Number of images: 224
# Processed: Temp=21.69°C, RH=30.98%
# Processing monthly data for March 2017...
# Number of images: 248
# Processed: Temp=26.34°C, RH=20.85%
# Processing monthly data for April 2017...
# Number of images: 240
# Processed: Temp=32.33°C, RH=14.41%
# Processing monthly data for May 2017...
# Number of images: 248
# Processed: Temp=35.31°C, RH=20.69%
# Processing monthly data for June 2017...
# Number of images: 240
# Processed: Temp=33.31°C, RH=42.5%
# Processing monthly data for July 2017...
# Number of images: 248
# Processed: Temp=27.62°C, RH=74.97%
# Processing monthly data for August 2017...
# Number of images: 248
# Processed: Temp=27.35°C, RH=76.45%
# Processing monthly data for September 2017...
# Number of images: 240
# Processed: Temp=27.21°C, RH=71.12%
# Processing monthly data for October 2017...
# Number of images: 248
# Processed: Temp=26.71°C, RH=49.44%
# Processing monthly data for November 2017...
# Number of images: 240
# Processed: Temp=22.24°C, RH=40.1%
# Processing monthly data for December 2017...
# Number of images: 248
# Processed: Temp=19.44°C, RH=37.37%
# Processing monthly data for January 2018...
# Number of images: 248
# Processed: Temp=18.57°C, RH=33.83%
# Processing monthly data for February 2018...
# Number of images: 224
# Processed: Temp=23.29°C, RH=31.04%
# Processing monthly data for March 2018...
# Number of images: 248
# Processed: Temp=28.75°C, RH=18.01%
# Processing monthly data for April 2018...
# Number of images: 240
# Processed: Temp=33.67°C, RH=16.28%
# Processing monthly data for May 2018...
# Number of images: 248
# Processed: Temp=37.11°C, RH=16.86%
# Processing monthly data for June 2018...
# Number of images: 240
# Processed: Temp=34.01°C, RH=41.05%
# Processing monthly data for July 2018...
# Number of images: 248
# Processed: Temp=28.29°C, RH=72.42%
# Processing monthly data for August 2018...
# Number of images: 248
# Processed: Temp=26.31°C, RH=81.6%
# Processing monthly data for September 2018...
# Number of images: 240
# Processed: Temp=25.51°C, RH=74.21%
# Processing monthly data for October 2018...
# Number of images: 248
# Processed: Temp=26.27°C, RH=42.39%
# Processing monthly data for November 2018...
# Number of images: 240
# Processed: Temp=23.04°C, RH=37.99%
# Processing monthly data for December 2018...
# Number of images: 248
# Processed: Temp=17.68°C, RH=39.25%
# Processing monthly data for January 2019...
# Number of images: 248
# Processed: Temp=17.48°C, RH=38.86%
# Processing monthly data for February 2019...
# Number of images: 224
# Processed: Temp=21.49°C, RH=35.73%
# Processing monthly data for March 2019...
# Number of images: 248
# Processed: Temp=26.72°C, RH=24.39%
# Processing monthly data for April 2019...
# Number of images: 240
# Processed: Temp=33.78°C, RH=16.39%
# Processing monthly data for May 2019...
# Number of images: 248
# Processed: Temp=36.17°C, RH=17.37%
# Processing monthly data for June 2019...
# Number of images: 240
# Processed: Temp=35.04°C, RH=34.19%
# Processing monthly data for July 2019...
# Number of images: 248
# Processed: Temp=28.87°C, RH=67.44%
# Processing monthly data for August 2019...
# Number of images: 248
# Processed: Temp=26.24°C, RH=83.16%
# Processing monthly data for September 2019...
# Number of images: 240
# Processed: Temp=25.71°C, RH=85.65%
# Processing monthly data for October 2019...
# Number of images: 248
# Processed: Temp=24.18°C, RH=67.53%
# Processing monthly data for November 2019...
# Number of images: 240
# Processed: Temp=22.74°C, RH=53.74%
# Processing monthly data for December 2019...
# Number of images: 248
# Processed: Temp=17.59°C, RH=52.81%
# Processing monthly data for January 2020...
# Number of images: 248
# Processed: Temp=16.96°C, RH=53.73%
# Processing monthly data for February 2020...
# Number of images: 232
# Processed: Temp=20.43°C, RH=34.63%
# Processing monthly data for March 2020...
# Number of images: 248
# Processed: Temp=25.37°C, RH=32.2%
# Processing monthly data for April 2020...
# Number of images: 240
# Processed: Temp=31.6°C, RH=19.52%
# Processing monthly data for May 2020...
# Number of images: 248
# Processed: Temp=34.49°C, RH=19.18%
# Processing monthly data for June 2020...
# Number of images: 240
# Processed: Temp=30.7°C, RH=53.49%
# Processing monthly data for July 2020...
# Number of images: 248
# Processed: Temp=29.45°C, RH=66.97%
# Processing monthly data for August 2020...
# Number of images: 248
# Processed: Temp=26.59°C, RH=82.74%
# Processing monthly data for September 2020...
# Number of images: 240
# Processed: Temp=27.25°C, RH=73.98%
# Processing monthly data for October 2020...
# Number of images: 248
# Processed: Temp=25.96°C, RH=52.06%
# Processing monthly data for November 2020...
# Number of images: 240
# Processed: Temp=21.48°C, RH=41.1%
# Processing monthly data for December 2020...
# Number of images: 248
# Processed: Temp=18.66°C, RH=41.81%
# Processing monthly data for January 2021...
# Number of images: 248
# Processed: Temp=18.99°C, RH=40.06%
# Processing monthly data for February 2021...
# Number of images: 224
# Processed: Temp=21.97°C, RH=25.15%
# Processing monthly data for March 2021...
# Number of images: 248
# Processed: Temp=28.07°C, RH=18.63%
# Processing monthly data for April 2021...
# Number of images: 240
# Processed: Temp=32.25°C, RH=14.14%
# Processing monthly data for May 2021...
# Number of images: 248
# Processed: Temp=32.77°C, RH=30.82%
# Processing monthly data for June 2021...
# Number of images: 240
# Processed: Temp=31.02°C, RH=51.58%
# Processing monthly data for July 2021...
# Number of images: 248
# Processed: Temp=29.14°C, RH=62.85%
# Processing monthly data for August 2021...
# Number of images: 248
# Processed: Temp=26.06°C, RH=80.38%
# Processing monthly data for September 2021...
# Number of images: 240
# Processed: Temp=25.83°C, RH=82.84%
# Processing monthly data for October 2021...
# Number of images: 248
# Processed: Temp=24.83°C, RH=61.04%
# Processing monthly data for November 2021...
# Number of images: 240
# Processed: Temp=21.3°C, RH=43.04%
# Processing monthly data for December 2021...
# Number of images: 248
# Processed: Temp=17.75°C, RH=47.02%
# Processing monthly data for January 2022...
# Number of images: 248
# Processed: Temp=16.44°C, RH=51.52%
# Processing monthly data for February 2022...
# Number of images: 224
# Processed: Temp=20.64°C, RH=30.76%
# Processing monthly data for March 2022...
# Number of images: 248
# Processed: Temp=28.64°C, RH=17.25%
# Processing monthly data for April 2022...
# Number of images: 240
# Processed: Temp=34.19°C, RH=12.85%
# Processing monthly data for May 2022...
# Number of images: 248
# Processed: Temp=35.21°C, RH=22.05%
# Processing monthly data for June 2022...
# Number of images: 240
# Processed: Temp=32.66°C, RH=40.14%
# Processing monthly data for July 2022...
# Number of images: 248
# Processed: Temp=27.86°C, RH=73.84%
# Processing monthly data for August 2022...
# Number of images: 248
# Processed: Temp=26.07°C, RH=81.36%
# Processing monthly data for September 2022...
# Number of images: 240
# Processed: Temp=26.01°C, RH=78.81%
# Processing monthly data for October 2022...
# Number of images: 248
# Processed: Temp=23.75°C, RH=63.28%
# Processing monthly data for November 2022...
# Number of images: 240
# Processed: Temp=20.91°C, RH=41.44%
# Processing monthly data for December 2022...
# Number of images: 248
# Processed: Temp=18.97°C, RH=40.31%
# Processing monthly data for January 2023...
# Number of images: 248
# Processed: Temp=17.24°C, RH=43.37%
# Processing monthly data for February 2023...
# Number of images: 224
# Processed: Temp=22.33°C, RH=23.48%
# Processing monthly data for March 2023...
# Number of images: 248
# Processed: Temp=26.26°C, RH=28.72%
# Processing monthly data for April 2023...
# Number of images: 240
# Processed: Temp=30.23°C, RH=24.22%
# Processing monthly data for May 2023...
# Number of images: 248
# Processed: Temp=33.18°C, RH=25.04%
# Processing monthly data for June 2023...
# Number of images: 240
# Processed: Temp=32.52°C, RH=41.26%
# Processing monthly data for July 2023...
# Number of images: 248
# Processed: Temp=28.54°C, RH=73.11%
# Processing monthly data for August 2023...
# Number of images: 248
# Processed: Temp=25.93°C, RH=78.74%
# Processing monthly data for September 2023...
# Number of images: 240
# Processed: Temp=26.37°C, RH=77.49%
# Processing monthly data for October 2023...
# Number of images: 248
# Processed: Temp=25.12°C, RH=50.13%
# Processing monthly data for November 2023...
# Number of images: 240
# Processed: Temp=22.18°C, RH=46.45%
# Processing monthly data for December 2023...
# Number of images: 248
# Processed: Temp=19.02°C, RH=48.91%
# Processing monthly data for January 2024...
# Number of images: 248
# Processed: Temp=17.94°C, RH=43.85%
# Processing monthly data for February 2024...
# Number of images: 232
# Processed: Temp=21.73°C, RH=35.37%
# Processing monthly data for March 2024...
# Number of images: 248
# Processed: Temp=26.99°C, RH=23.34%
# Processing monthly data for April 2024...
# Number of images: 240
# Processed: Temp=31.98°C, RH=24.14%
# Processing monthly data for May 2024...
# Number of images: 248
# Processed: Temp=35.65°C, RH=21.66%
# Processing monthly data for June 2024...
# Number of images: 240
# Processed: Temp=33.42°C, RH=42.95%
# Processing monthly data for July 2024...
# Number of images: 248
# Processed: Temp=28.63°C, RH=74.29%
# Processing monthly data for August 2024...
# Number of images: 248
# Processed: Temp=25.99°C, RH=84.2%
# Processing monthly data for September 2024...
# Number of images: 240
# Processed: Temp=25.94°C, RH=82.5%
# Processing monthly data for October 2024...
# Number of images: 248
# Processed: Temp=25.95°C, RH=59.36%
# Processing monthly data for November 2024...
# Number of images: 240
# Processed: Temp=21.73°C, RH=41.77%
# Processing monthly data for December 2024...
# Number of images: 120
# Processed: Temp=17.93°C, RH=37.34%
# Processing monthly data for January 2025...
# Number of images: 0
# No data available
# Monthly data exported to mp_monthly_humidity_data.csv
#
# Monthly data sample:
#    Year  Month Month_Name  Temperature_K  Temperature_C  Pressure_Pa  \
# 0  2015      1    January         289.39          16.24     96900.35
# 1  2015      2   February         295.12          21.97     96660.11
# 2  2015      3      March         298.35          25.20     96609.70
# 3  2015      4      April         304.21          31.06     96098.34
# 4  2015      5        May         308.97          35.82     95767.75
#
#    Specific_Humidity  Relative_Humidity  Temperature_StdDev  Pressure_StdDev  \
# 0             0.0061              51.55                1.66          1579.72
# 1             0.0060              35.18                1.41          1533.81
# 2             0.0070              33.94                1.28          1520.31
# 3             0.0072              24.59                1.33          1479.22
# 4             0.0070              18.49                1.63          1441.30
#
#    Specific_Humidity_StdDev
# 0                    0.0004
# 1                    0.0004
# 2                    0.0005
# 3                    0.0006
# 4                    0.0012
#
# Processing annual averages...
# Processing annual data for 2015...
# Processed: Temp=26.3°C, RH=45.0%
# Processing annual data for 2016...
# Processed: Temp=26.31°C, RH=46.04%
# Processing annual data for 2017...
# Processed: Temp=26.45°C, RH=44.25%
# Processing annual data for 2018...
# Processed: Temp=26.88°C, RH=41.88%
# Processing annual data for 2019...
# Processed: Temp=26.34°C, RH=47.05%
# Processing annual data for 2020...
# Processed: Temp=25.75°C, RH=48.51%
# Processing annual data for 2021...
# Processed: Temp=25.84°C, RH=47.14%
# Processing annual data for 2022...
# Processed: Temp=25.96°C, RH=45.5%
# Processing annual data for 2023...
# Processed: Temp=25.75°C, RH=47.7%
# Processing annual data for 2024...
# Processed: Temp=26.53°C, RH=48.38%
# Processing annual data for 2025...
# No data available
# Annual data exported to mp_annual_humidity_data.csv
#
# Annual data:
#    Year  Temperature_K  Temperature_C  Pressure_Pa  Specific_Humidity  \
# 0  2015         299.45          26.30     96227.84             0.0100
# 1  2016         299.46          26.31     96146.19             0.0102
# 2  2017         299.60          26.45     96143.54             0.0099
# 3  2018         300.03          26.88     96130.16             0.0096
# 4  2019         299.49          26.34     96148.87             0.0105
# 5  2020         298.90          25.75     96113.95             0.0105
# 6  2021         298.99          25.84     96083.73             0.0102
# 7  2022         299.11          25.96     96047.05             0.0099
# 8  2023         298.90          25.75     96189.04             0.0103
# 9  2024         299.68          26.53     96073.72             0.0109
#
#    Relative_Humidity  Temperature_StdDev  Pressure_StdDev  \
# 0              45.00                1.25          1494.20
# 1              46.04                1.14          1493.37
# 2              44.25                1.08          1493.21
# 3              41.88                1.08          1491.24
# 4              47.05                0.92          1483.59
# 5              48.51                0.92          1472.70
# 6              47.14                0.97          1469.10
# 7              45.50                0.95          1471.93
# 8              47.70                0.88          1475.90
# 9              48.38                0.92          1468.89
#
#    Specific_Humidity_StdDev
# 0                    0.0006
# 1                    0.0004
# 2                    0.0005
# 3                    0.0004
# 4                    0.0004
# 5                    0.0005
# 6                    0.0004
# 7                    0.0004
# 8                    0.0003
# 9                    0.0006
#
# Monthly Summary Statistics:
#              mean    min    max   std
# Month_Name
# April       18.26  12.85  24.59  4.54
# August      80.92  75.12  85.43  3.31
# December    42.30  37.34  52.81  5.39
# February    31.37  23.48  35.73  4.24
# January     44.38  33.83  53.73  6.35
# July        71.18  62.85  77.36  4.51
# June        43.11  34.19  53.49  5.59
# March       24.22  17.25  33.94  5.86
# May         21.55  16.86  30.82  4.17
# November    42.34  35.13  53.74  5.01
# October     54.31  41.92  67.53  8.63
# September   76.45  60.53  85.65  7.17
#
# Annual Summary Statistics:
# mean    46.14
# min     41.88
# max     48.51
# std      2.06
# Name: Relative_Humidity, dtype: float64

# %% [markdown]
# ## Export Precipitation

# %%
import ee
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import calendar

# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project='ee-geosynta')

def get_mp_boundary():
    """Get Madhya Pradesh's administrative boundary"""
    states = ee.FeatureCollection('FAO/GAUL/2015/level1')
    mp = states.filter(ee.Filter.eq('ADM1_NAME', 'Madhya Pradesh')).geometry()
    return mp

def calculate_monthly_precipitation():
    """Calculate monthly precipitation averages for Madhya Pradesh"""
    chirps = ee.ImageCollection('UCSB-CHG/CHIRPS/PENTAD').select('precipitation')
    roi = get_mp_boundary()

    current_year = datetime.now().year
    current_month = datetime.now().month

    monthly_data = []

    for year in range(2015, current_year + 1):
        for month in range(1, 13):
            if year == current_year and month > current_month:
                continue

            try:
                print(f"Processing monthly data for {calendar.month_name[month]} {year}...")

                monthly_collection = chirps.filter(ee.Filter.calendarRange(year, year, 'year')) \
                                        .filter(ee.Filter.calendarRange(month, month, 'month'))

                num_images = monthly_collection.size().getInfo()
                print(f"Number of images: {num_images}")

                if num_images == 0:
                    print(f"No data available")
                    continue

                # Calculate monthly statistics
                monthly_stats = monthly_collection.reduce(ee.Reducer.mean() \
                    .combine(ee.Reducer.sum(), '', True) \
                    .combine(ee.Reducer.stdDev(), '', True) \
                    .combine(ee.Reducer.minMax(), '', True))

                stats = monthly_stats.reduceRegion(
                    reducer=ee.Reducer.mean(),
                    geometry=roi,
                    scale=5000,
                    maxPixels=1e9
                ).getInfo()

                if stats['precipitation_mean'] is not None:
                    monthly_data.append({
                        'Year': year,
                        'Month': month,
                        'Month_Name': calendar.month_name[month],
                        'Mean_Daily_Precipitation_mm': round(stats['precipitation_mean'], 2),
                        'Total_Monthly_Precipitation_mm': round(stats['precipitation_sum'], 2),
                        'Max_Daily_Precipitation_mm': round(stats['precipitation_max'], 2),
                        'Min_Daily_Precipitation_mm': round(stats['precipitation_min'], 2),
                        'StdDev_Precipitation_mm': round(stats['precipitation_stdDev'], 2)
                    })
                    print(f"Processed: Mean={monthly_data[-1]['Mean_Daily_Precipitation_mm']}mm/day, "
                          f"Total={monthly_data[-1]['Total_Monthly_Precipitation_mm']}mm/month")

            except Exception as e:
                print(f"Error processing {calendar.month_name[month]} {year}: {str(e)}")

    return pd.DataFrame(monthly_data)

def calculate_annual_precipitation():
    """Calculate annual precipitation averages for Madhya Pradesh"""
    chirps = ee.ImageCollection('UCSB-CHG/CHIRPS/PENTAD').select('precipitation')
    roi = get_mp_boundary()

    current_year = datetime.now().year
    annual_data = []

    for year in range(2015, current_year + 1):
        try:
            print(f"Processing annual data for {year}...")

            yearly_collection = chirps.filter(ee.Filter.calendarRange(year, year, 'year'))

            if yearly_collection.size().getInfo() == 0:
                print(f"No data available")
                continue

            # Calculate annual statistics
            yearly_stats = yearly_collection.reduce(ee.Reducer.mean() \
                .combine(ee.Reducer.sum(), '', True) \
                .combine(ee.Reducer.stdDev(), '', True) \
                .combine(ee.Reducer.minMax(), '', True))

            stats = yearly_stats.reduceRegion(
                reducer=ee.Reducer.mean(),
                geometry=roi,
                scale=5000,
                maxPixels=1e9
            ).getInfo()

            if stats['precipitation_mean'] is not None:
                annual_data.append({
                    'Year': year,
                    'Mean_Daily_Precipitation_mm': round(stats['precipitation_mean'], 2),
                    'Total_Annual_Precipitation_mm': round(stats['precipitation_sum'], 2),
                    'Max_Daily_Precipitation_mm': round(stats['precipitation_max'], 2),
                    'Min_Daily_Precipitation_mm': round(stats['precipitation_min'], 2),
                    'StdDev_Precipitation_mm': round(stats['precipitation_stdDev'], 2)
                })
                print(f"Processed: Mean={annual_data[-1]['Mean_Daily_Precipitation_mm']}mm/day, "
                      f"Total={annual_data[-1]['Total_Annual_Precipitation_mm']}mm/year")

        except Exception as e:
            print(f"Error processing {year}: {str(e)}")

    return pd.DataFrame(annual_data)

def analyze_seasonal_patterns(monthly_df):
    """Analyze seasonal patterns in precipitation"""
    # Define seasons (Indian meteorological seasons)
    winter = ['December', 'January', 'February']
    pre_monsoon = ['March', 'April', 'May']
    monsoon = ['June', 'July', 'August', 'September']
    post_monsoon = ['October', 'November']

    monthly_df['Season'] = monthly_df['Month_Name'].apply(lambda x:
        'Winter' if x in winter else
        'Pre-monsoon' if x in pre_monsoon else
        'Monsoon' if x in monsoon else
        'Post-monsoon')

    seasonal_stats = monthly_df.groupby(['Year', 'Season'])['Total_Monthly_Precipitation_mm'].sum().reset_index()
    seasonal_stats = seasonal_stats.rename(columns={'Total_Monthly_Precipitation_mm': 'Total_Seasonal_Precipitation_mm'})

    return seasonal_stats

def export_precipitation_data():
    """Export precipitation data for Madhya Pradesh"""
    try:
        # Calculate and export monthly data
        print("\nProcessing monthly averages...")
        monthly_df = calculate_monthly_precipitation()
        monthly_output = 'mp_monthly_precipitation_data.csv'
        monthly_df.to_csv(monthly_output, index=False)
        print(f"Monthly data exported to {monthly_output}")
        print("\nMonthly data sample:")
        print(monthly_df.head())

        # Calculate and export annual data
        print("\nProcessing annual averages...")
        annual_df = calculate_annual_precipitation()
        annual_output = 'mp_annual_precipitation_data.csv'
        annual_df.to_csv(annual_output, index=False)
        print(f"Annual data exported to {annual_output}")
        print("\nAnnual data:")
        print(annual_df)

        # Calculate and export seasonal patterns
        print("\nAnalyzing seasonal patterns...")
        seasonal_df = analyze_seasonal_patterns(monthly_df)
        seasonal_output = 'mp_seasonal_precipitation_data.csv'
        seasonal_df.to_csv(seasonal_output, index=False)
        print(f"Seasonal data exported to {seasonal_output}")

        # Generate summary statistics
        print("\nMonthly Summary Statistics:")
        monthly_stats = monthly_df.groupby('Month_Name')['Total_Monthly_Precipitation_mm'] \
                                .agg(['mean', 'min', 'max', 'std']).round(2)
        print(monthly_stats)

        print("\nAnnual Summary Statistics:")
        annual_stats = annual_df['Total_Annual_Precipitation_mm'].agg(['mean', 'min', 'max', 'std']).round(2)
        print(annual_stats)

    except Exception as e:
        print(f"An error occurred: {str(e)}")
        print("Please check:")
        print("1. Earth Engine authentication is valid")
        print("2. Internet connection is stable")
        print("3. The specified region has available data")

if __name__ == "__main__":
    export_precipitation_data()
# Out:
# Processing monthly averages...
# Processing monthly data for January 2015...
# Number of images: 6
# Processed: Mean=3.59mm/day, Total=21.52mm/month
# Processing monthly data for February 2015...
# Number of images: 6
# Processed: Mean=1.68mm/day, Total=10.05mm/month
# Processing monthly data for March 2015...
# Number of images: 6
# Processed: Mean=4.53mm/day, Total=27.2mm/month
# Processing monthly data for April 2015...
# Number of images: 6
# Processed: Mean=0.88mm/day, Total=5.25mm/month
# Processing monthly data for May 2015...
# Number of images: 6
# Processed: Mean=0.93mm/day, Total=5.58mm/month
# Processing monthly data for June 2015...
# Number of images: 6
# Processed: Mean=22.57mm/day, Total=135.42mm/month
# Processing monthly data for July 2015...
# Number of images: 6
# Processed: Mean=54.7mm/day, Total=328.17mm/month
# Processing monthly data for August 2015...
# Number of images: 6
# Processed: Mean=46.73mm/day, Total=280.38mm/month
# Processing monthly data for September 2015...
# Number of images: 6
# Processed: Mean=16.31mm/day, Total=97.83mm/month
# Processing monthly data for October 2015...
# Number of images: 6
# Processed: Mean=2.9mm/day, Total=17.41mm/month
# Processing monthly data for November 2015...
# Number of images: 6
# Processed: Mean=0.97mm/day, Total=5.85mm/month
# Processing monthly data for December 2015...
# Number of images: 6
# Processed: Mean=0.68mm/day, Total=4.07mm/month
# Processing monthly data for January 2016...
# Number of images: 6
# Processed: Mean=1.88mm/day, Total=11.28mm/month
# Processing monthly data for February 2016...
# Number of images: 6
# Processed: Mean=1.56mm/day, Total=9.33mm/month
# Processing monthly data for March 2016...
# Number of images: 6
# Processed: Mean=2.0mm/day, Total=12.01mm/month
# Processing monthly data for April 2016...
# Number of images: 6
# Processed: Mean=0.42mm/day, Total=2.54mm/month
# Processing monthly data for May 2016...
# Number of images: 6
# Processed: Mean=1.77mm/day, Total=10.6mm/month
# Processing monthly data for June 2016...
# Number of images: 6
# Processed: Mean=20.96mm/day, Total=125.76mm/month
# Processing monthly data for July 2016...
# Number of images: 6
# Processed: Mean=96.72mm/day, Total=580.34mm/month
# Processing monthly data for August 2016...
# Number of images: 6
# Processed: Mean=73.63mm/day, Total=441.78mm/month
# Processing monthly data for September 2016...
# Number of images: 6
# Processed: Mean=26.4mm/day, Total=158.38mm/month
# Processing monthly data for October 2016...
# Number of images: 6
# Processed: Mean=6.9mm/day, Total=41.43mm/month
# Processing monthly data for November 2016...
# Number of images: 6
# Processed: Mean=0.64mm/day, Total=3.81mm/month
# Processing monthly data for December 2016...
# Number of images: 6
# Processed: Mean=0.64mm/day, Total=3.84mm/month
# Processing monthly data for January 2017...
# Number of images: 6
# Processed: Mean=1.67mm/day, Total=10.04mm/month
# Processing monthly data for February 2017...
# Number of images: 6
# Processed: Mean=0.93mm/day, Total=5.6mm/month
# Processing monthly data for March 2017...
# Number of images: 6
# Processed: Mean=0.93mm/day, Total=5.56mm/month
# Processing monthly data for April 2017...
# Number of images: 6
# Processed: Mean=0.4mm/day, Total=2.37mm/month
# Processing monthly data for May 2017...
# Number of images: 6
# Processed: Mean=1.49mm/day, Total=8.92mm/month
# Processing monthly data for June 2017...
# Number of images: 6
# Processed: Mean=22.97mm/day, Total=137.81mm/month
# Processing monthly data for July 2017...
# Number of images: 6
# Processed: Mean=56.26mm/day, Total=337.58mm/month
# Processing monthly data for August 2017...
# Number of images: 6
# Processed: Mean=37.6mm/day, Total=225.62mm/month
# Processing monthly data for September 2017...
# Number of images: 6
# Processed: Mean=30.52mm/day, Total=183.12mm/month
# Processing monthly data for October 2017...
# Number of images: 6
# Processed: Mean=2.98mm/day, Total=17.87mm/month
# Processing monthly data for November 2017...
# Number of images: 6
# Processed: Mean=0.74mm/day, Total=4.42mm/month
# Processing monthly data for December 2017...
# Number of images: 6
# Processed: Mean=0.89mm/day, Total=5.33mm/month
# Processing monthly data for January 2018...
# Number of images: 6
# Processed: Mean=1.6mm/day, Total=9.58mm/month
# Processing monthly data for February 2018...
# Number of images: 6
# Processed: Mean=2.52mm/day, Total=15.1mm/month
# Processing monthly data for March 2018...
# Number of images: 6
# Processed: Mean=0.83mm/day, Total=4.99mm/month
# Processing monthly data for April 2018...
# Number of images: 6
# Processed: Mean=0.79mm/day, Total=4.76mm/month
# Processing monthly data for May 2018...
# Number of images: 6
# Processed: Mean=1.16mm/day, Total=6.97mm/month
# Processing monthly data for June 2018...
# Number of images: 6
# Processed: Mean=21.63mm/day, Total=129.79mm/month
# Processing monthly data for July 2018...
# Number of images: 6
# Processed: Mean=69.84mm/day, Total=419.04mm/month
# Processing monthly data for August 2018...
# Number of images: 6
# Processed: Mean=55.23mm/day, Total=331.39mm/month
# Processing monthly data for September 2018...
# Number of images: 6
# Processed: Mean=23.7mm/day, Total=142.18mm/month
# Processing monthly data for October 2018...
# Number of images: 6
# Processed: Mean=1.53mm/day, Total=9.16mm/month
# Processing monthly data for November 2018...
# Number of images: 6
# Processed: Mean=0.78mm/day, Total=4.68mm/month
# Processing monthly data for December 2018...
# Number of images: 6
# Processed: Mean=0.86mm/day, Total=5.16mm/month
# Processing monthly data for January 2019...
# Number of images: 6
# Processed: Mean=2.4mm/day, Total=14.41mm/month
# Processing monthly data for February 2019...
# Number of images: 6
# Processed: Mean=1.74mm/day, Total=10.44mm/month
# Processing monthly data for March 2019...
# Number of images: 6
# Processed: Mean=1.28mm/day, Total=7.7mm/month
# Processing monthly data for April 2019...
# Number of images: 6
# Processed: Mean=1.09mm/day, Total=6.53mm/month
# Processing monthly data for May 2019...
# Number of images: 6
# Processed: Mean=0.93mm/day, Total=5.59mm/month
# Processing monthly data for June 2019...
# Number of images: 6
# Processed: Mean=16.0mm/day, Total=95.98mm/month
# Processing monthly data for July 2019...
# Number of images: 6
# Processed: Mean=63.23mm/day, Total=379.39mm/month
# Processing monthly data for August 2019...
# Number of images: 6
# Processed: Mean=81.49mm/day, Total=488.97mm/month
# Processing monthly data for September 2019...
# Number of images: 6
# Processed: Mean=78.12mm/day, Total=468.72mm/month
# Processing monthly data for October 2019...
# Number of images: 6
# Processed: Mean=5.54mm/day, Total=33.25mm/month
# Processing monthly data for November 2019...
# Number of images: 6
# Processed: Mean=1.21mm/day, Total=7.25mm/month
# Processing monthly data for December 2019...
# Number of images: 6
# Processed: Mean=1.32mm/day, Total=7.9mm/month
# Processing monthly data for January 2020...
# Number of images: 6
# Processed: Mean=3.39mm/day, Total=20.33mm/month
# Processing monthly data for February 2020...
# Number of images: 6
# Processed: Mean=1.6mm/day, Total=9.57mm/month
# Processing monthly data for March 2020...
# Number of images: 6
# Processed: Mean=3.35mm/day, Total=20.11mm/month
# Processing monthly data for April 2020...
# Number of images: 6
# Processed: Mean=0.89mm/day, Total=5.34mm/month
# Processing monthly data for May 2020...
# Number of images: 6
# Processed: Mean=1.53mm/day, Total=9.18mm/month
# Processing monthly data for June 2020...
# Number of images: 6
# Processed: Mean=33.28mm/day, Total=199.68mm/month
# Processing monthly data for July 2020...
# Number of images: 6
# Processed: Mean=39.07mm/day, Total=234.42mm/month
# Processing monthly data for August 2020...
# Number of images: 6
# Processed: Mean=74.63mm/day, Total=447.75mm/month
# Processing monthly data for September 2020...
# Number of images: 6
# Processed: Mean=34.98mm/day, Total=209.88mm/month
# Processing monthly data for October 2020...
# Number of images: 6
# Processed: Mean=4.65mm/day, Total=27.9mm/month
# Processing monthly data for November 2020...
# Number of images: 6
# Processed: Mean=1.0mm/day, Total=6.0mm/month
# Processing monthly data for December 2020...
# Number of images: 6
# Processed: Mean=1.01mm/day, Total=6.04mm/month
# Processing monthly data for January 2021...
# Number of images: 6
# Processed: Mean=1.83mm/day, Total=10.98mm/month
# Processing monthly data for February 2021...
# Number of images: 6
# Processed: Mean=1.2mm/day, Total=7.18mm/month
# Processing monthly data for March 2021...
# Number of images: 6
# Processed: Mean=2.02mm/day, Total=12.1mm/month
# Processing monthly data for April 2021...
# Number of images: 6
# Processed: Mean=0.52mm/day, Total=3.14mm/month
# Processing monthly data for May 2021...
# Number of images: 6
# Processed: Mean=4.23mm/day, Total=25.35mm/month
# Processing monthly data for June 2021...
# Number of images: 6
# Processed: Mean=25.83mm/day, Total=154.99mm/month
# Processing monthly data for July 2021...
# Number of images: 6
# Processed: Mean=47.25mm/day, Total=283.52mm/month
# Processing monthly data for August 2021...
# Number of images: 6
# Processed: Mean=45.09mm/day, Total=270.53mm/month
# Processing monthly data for September 2021...
# Number of images: 6
# Processed: Mean=48.45mm/day, Total=290.71mm/month
# Processing monthly data for October 2021...
# Number of images: 6
# Processed: Mean=8.8mm/day, Total=52.83mm/month
# Processing monthly data for November 2021...
# Number of images: 6
# Processed: Mean=0.85mm/day, Total=5.12mm/month
# Processing monthly data for December 2021...
# Number of images: 6
# Processed: Mean=1.84mm/day, Total=11.02mm/month
# Processing monthly data for January 2022...
# Number of images: 6
# Processed: Mean=4.1mm/day, Total=24.58mm/month
# Processing monthly data for February 2022...
# Number of images: 6
# Processed: Mean=1.47mm/day, Total=8.82mm/month
# Processing monthly data for March 2022...
# Number of images: 6
# Processed: Mean=0.94mm/day, Total=5.61mm/month
# Processing monthly data for April 2022...
# Number of images: 6
# Processed: Mean=0.4mm/day, Total=2.42mm/month
# Processing monthly data for May 2022...
# Number of images: 6
# Processed: Mean=1.24mm/day, Total=7.46mm/month
# Processing monthly data for June 2022...
# Number of images: 6
# Processed: Mean=22.98mm/day, Total=137.89mm/month
# Processing monthly data for July 2022...
# Number of images: 6
# Processed: Mean=74.54mm/day, Total=447.23mm/month
# Processing monthly data for August 2022...
# Number of images: 6
# Processed: Mean=80.21mm/day, Total=481.24mm/month
# Processing monthly data for September 2022...
# Number of images: 6
# Processed: Mean=41.04mm/day, Total=246.22mm/month
# Processing monthly data for October 2022...
# Number of images: 6
# Processed: Mean=13.99mm/day, Total=83.91mm/month
# Processing monthly data for November 2022...
# Number of images: 6
# Processed: Mean=0.64mm/day, Total=3.85mm/month
# Processing monthly data for December 2022...
# Number of images: 6
# Processed: Mean=0.92mm/day, Total=5.49mm/month
# Processing monthly data for January 2023...
# Number of images: 6
# Processed: Mean=2.14mm/day, Total=12.86mm/month
# Processing monthly data for February 2023...
# Number of images: 6
# Processed: Mean=0.84mm/day, Total=5.02mm/month
# Processing monthly data for March 2023...
# Number of images: 6
# Processed: Mean=3.01mm/day, Total=18.03mm/month
# Processing monthly data for April 2023...
# Number of images: 6
# Processed: Mean=1.78mm/day, Total=10.68mm/month
# Processing monthly data for May 2023...
# Number of images: 6
# Processed: Mean=3.97mm/day, Total=23.81mm/month
# Processing monthly data for June 2023...
# Number of images: 6
# Processed: Mean=23.91mm/day, Total=143.49mm/month
# Processing monthly data for July 2023...
# Number of images: 6
# Processed: Mean=57.55mm/day, Total=345.29mm/month
# Processing monthly data for August 2023...
# Number of images: 6
# Processed: Mean=27.17mm/day, Total=163.03mm/month
# Processing monthly data for September 2023...
# Number of images: 6
# Processed: Mean=48.23mm/day, Total=289.39mm/month
# Processing monthly data for October 2023...
# Number of images: 6
# Processed: Mean=1.7mm/day, Total=10.2mm/month
# Processing monthly data for November 2023...
# Number of images: 6
# Processed: Mean=2.41mm/day, Total=14.49mm/month
# Processing monthly data for December 2023...
# Number of images: 6
# Processed: Mean=1.52mm/day, Total=9.14mm/month
# Processing monthly data for January 2024...
# Number of images: 6
# Processed: Mean=2.26mm/day, Total=13.55mm/month
# Processing monthly data for February 2024...
# Number of images: 6
# Processed: Mean=2.2mm/day, Total=13.18mm/month
# Processing monthly data for March 2024...
# Number of images: 6
# Processed: Mean=2.07mm/day, Total=12.4mm/month
# Processing monthly data for April 2024...
# Number of images: 6
# Processed: Mean=1.29mm/day, Total=7.72mm/month
# Processing monthly data for May 2024...
# Number of images: 6
# Processed: Mean=1.31mm/day, Total=7.84mm/month
# Processing monthly data for June 2024...
# Number of images: 6
# Processed: Mean=26.13mm/day, Total=156.8mm/month
# Processing monthly data for July 2024...
# Number of images: 6
# Processed: Mean=69.37mm/day, Total=416.21mm/month
# Processing monthly data for August 2024...
# Number of images: 6
# Processed: Mean=67.17mm/day, Total=403.03mm/month
# Processing monthly data for September 2024...
# Number of images: 6
# Processed: Mean=43.17mm/day, Total=259.0mm/month
# Processing monthly data for October 2024...
# Number of images: 6
# Processed: Mean=4.76mm/day, Total=28.53mm/month
# Processing monthly data for November 2024...
# Number of images: 6
# Processed: Mean=0.66mm/day, Total=3.93mm/month
# Processing monthly data for December 2024...
# Number of images: 0
# No data available
# Processing monthly data for January 2025...
# Number of images: 0
# No data available
# Monthly data exported to mp_monthly_precipitation_data.csv
#
# Monthly data sample:
#    Year  Month Month_Name  Mean_Daily_Precipitation_mm  \
# 0  2015      1    January                         3.59
# 1  2015      2   February                         1.68
# 2  2015      3      March                         4.53
# 3  2015      4      April                         0.88
# 4  2015      5        May                         0.93
#
#    Total_Monthly_Precipitation_mm  Max_Daily_Precipitation_mm  \
# 0                           21.52                        5.78
# 1                           10.05                        4.60
# 2                           27.20                       11.08
# 3                            5.25                        2.22
# 4                            5.58                        3.50
#
#    Min_Daily_Precipitation_mm  StdDev_Precipitation_mm
# 0                        2.77                     1.06
# 1                        0.72                     1.41
# 2                        1.16                     3.65
# 3                        0.45                     0.63
# 4                        0.08                     1.21
#
# Processing annual averages...
# Processing annual data for 2015...
# Processed: Mean=13.04mm/day, Total=938.73mm/year
# Processing annual data for 2016...
# Processed: Mean=19.46mm/day, Total=1401.09mm/year
# Processing annual data for 2017...
# Processed: Mean=13.11mm/day, Total=944.24mm/year
# Processing annual data for 2018...
# Processed: Mean=15.04mm/day, Total=1082.81mm/year
# Processing annual data for 2019...
# Processed: Mean=21.2mm/day, Total=1526.13mm/year
# Processing annual data for 2020...
# Processed: Mean=16.61mm/day, Total=1196.21mm/year
# Processing annual data for 2021...
# Processed: Mean=15.66mm/day, Total=1127.47mm/year
# Processing annual data for 2022...
# Processed: Mean=20.2mm/day, Total=1454.71mm/year
# Processing annual data for 2023...
# Processed: Mean=14.52mm/day, Total=1045.42mm/year
# Processing annual data for 2024...
# Processed: Mean=20.03mm/day, Total=1322.19mm/year
# Processing annual data for 2025...
# No data available
# Annual data exported to mp_annual_precipitation_data.csv
#
# Annual data:
#    Year  Mean_Daily_Precipitation_mm  Total_Annual_Precipitation_mm  \
# 0  2015                        13.04                         938.73
# 1  2016                        19.46                        1401.09
# 2  2017                        13.11                         944.24
# 3  2018                        15.04                        1082.81
# 4  2019                        21.20                        1526.13
# 5  2020                        16.61                        1196.21
# 6  2021                        15.66                        1127.47
# 7  2022                        20.20                        1454.71
# 8  2023                        14.52                        1045.42
# 9  2024                        20.03                        1322.19
#
#    Max_Daily_Precipitation_mm  Min_Daily_Precipitation_mm  \
# 0                      130.19                        0.04
# 1                      209.62                        0.06
# 2                      122.62                        0.03
# 3                      132.30                        0.04
# 4                      165.40                        0.04
# 5                      146.68                        0.05
# 6                      131.08                        0.06
# 7                      166.22                        0.03
# 8                      123.80                        0.06
# 9                      158.52                        0.05
#
#    StdDev_Precipitation_mm
# 0                    26.02
# 1                    38.63
# 2                    25.40
# 3                    29.17
# 4                    37.90
# 5                    28.15
# 6                    26.62
# 7                    36.21
# 8                    27.35
# 9                    34.13
#
# Analyzing seasonal patterns...
# Seasonal data exported to mp_seasonal_precipitation_data.csv
#
# Monthly Summary Statistics:
#               mean     min     max     std
# Month_Name
# April         5.08    2.37   10.68    2.69
# August      353.37  163.03  488.97  115.06
# December      6.44    3.84   11.02    2.42
# February      9.43    5.02   15.10    3.11
# January      14.91    9.58   24.58    5.31
# July        377.12  234.42  580.34   96.38
# June        141.76   95.98  199.68   26.51
# March        12.57    4.99   27.20    7.30
# May          11.13    5.58   25.35    7.27
# November      5.94    3.81   14.49    3.20
# October      32.25    9.16   83.91   22.75
# September   234.54   97.83  468.72  104.36
#
# Annual Summary Statistics:
# mean    1203.90
# min      938.73
# max     1526.13
# std      211.62
# Name: Total_Annual_Precipitation_mm, dtype: float64

# %% [markdown]
# ## Export Rain Fall

# %%
import ee
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import calendar

# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project='ee-geosynta')

def get_mp_boundary():
    """Get Madhya Pradesh's administrative boundary"""
    states = ee.FeatureCollection('FAO/GAUL/2015/level1')
    mp = states.filter(ee.Filter.eq('ADM1_NAME', 'Madhya Pradesh')).geometry()
    return mp

def calculate_monthly_rainfall():
    """Calculate monthly rainfall averages for Madhya Pradesh using GPM V07 data"""
    gpm = ee.ImageCollection('NASA/GPM_L3/IMERG_V07')
    roi = get_mp_boundary()

    current_year = datetime.now().year
    current_month = datetime.now().month

    monthly_data = []

    for year in range(2015, current_year + 1):
        for month in range(1, 13):
            if year == current_year and month > current_month:
                continue

            try:
                print(f"Processing monthly data for {calendar.month_name[month]} {year}...")

                start_date = ee.Date.fromYMD(year, month, 1)
                if month == 12:
                    end_date = ee.Date.fromYMD(year + 1, 1, 1)
                else:
                    end_date = ee.Date.fromYMD(year, month + 1, 1)

                # Get half-hourly precipitation data
                collection = gpm.filter(ee.Filter.date(start_date, end_date)) \
                             .select('precipitation')

                # Get unique dates
                dates = collection.aggregate_array('system:time_start') \
                    .map(lambda t: ee.Date(t).format('YYYY-MM-dd')).distinct()
                dates_list = dates.getInfo()

                daily_totals = []
                rainy_days = 0

                for date in dates_list:
                    # Get all images for this date
                    day_images = collection.filter(
                        ee.Filter.eq('system:time_start', ee.Date.parse('YYYY-MM-dd', date).millis())
                    )

                    # Calculate total precipitation for this day
                    daily_total = day_images.sum().reduceRegion(
                        reducer=ee.Reducer.mean(),
                        geometry=roi,
                        scale=11132,
                        maxPixels=1e9
                    ).get('precipitation').getInfo()

                    # Convert from half-hourly to daily total
                    daily_total = daily_total * 24  # Convert to daily total
                    daily_totals.append(daily_total)

                    # Count as rainy day if daily total > 2.5mm (standard meteorological threshold)
                    if daily_total > 2.5:
                        rainy_days += 1

                if daily_totals:
                    # Calculate monthly statistics
                    monthly_total = sum(daily_totals)
                    daily_mean = monthly_total / len(daily_totals)

                    monthly_data.append({
                        'Year': year,
                        'Month': month,
                        'Month_Name': calendar.month_name[month],
                        'Mean_Daily_Rainfall_mm': round(daily_mean, 2),
                        'Total_Monthly_Rainfall_mm': round(monthly_total, 2),
                        'Max_Daily_Rainfall_mm': round(max(daily_totals), 2),
                        'Min_Daily_Rainfall_mm': round(min(daily_totals), 2),
                        'Rainy_Days': rainy_days,
                        'Days_In_Month': len(daily_totals)
                    })

                    print(f"Processed: Mean={monthly_data[-1]['Mean_Daily_Rainfall_mm']}mm/day, "
                          f"Total={monthly_data[-1]['Total_Monthly_Rainfall_mm']}mm/month, "
                          f"Rainy Days={monthly_data[-1]['Rainy_Days']} out of {monthly_data[-1]['Days_In_Month']} days")

            except Exception as e:
                print(f"Error processing {calendar.month_name[month]} {year}: {str(e)}")

    return pd.DataFrame(monthly_data)

def calculate_annual_rainfall():
    """Calculate annual rainfall averages for Madhya Pradesh"""
    gpm = ee.ImageCollection('NASA/GPM_L3/IMERG_V07')
    roi = get_mp_boundary()

    current_year = datetime.now().year
    annual_data = []

    for year in range(2015, current_year + 1):
        try:
            print(f"Processing annual data for {year}...")

            start_date = ee.Date.fromYMD(year, 1, 1)
            end_date = ee.Date.fromYMD(year + 1, 1, 1)

            # Get precipitation data for the year
            collection = gpm.filter(ee.Filter.date(start_date, end_date)) \
                           .select('precipitation')

            # Get unique dates
            dates = collection.aggregate_array('system:time_start') \
                .map(lambda t: ee.Date(t).format('YYYY-MM-dd')).distinct()
            dates_list = dates.getInfo()

            daily_totals = []
            rainy_days = 0

            for date in dates_list:
                # Get all images for this date
                day_images = collection.filter(
                    ee.Filter.eq('system:time_start', ee.Date.parse('YYYY-MM-dd', date).millis())
                )

                # Calculate total precipitation for this day
                daily_total = day_images.sum().reduceRegion(
                    reducer=ee.Reducer.mean(),
                    geometry=roi,
                    scale=11132,
                    maxPixels=1e9
                ).get('precipitation').getInfo()

                # Convert from half-hourly to daily total
                daily_total = daily_total * 24  # Convert to daily total
                daily_totals.append(daily_total)

                # Count as rainy day if daily total > 2.5mm
                if daily_total > 2.5:
                    rainy_days += 1

            if daily_totals:
                # Calculate annual statistics
                annual_total = sum(daily_totals)
                daily_mean = annual_total / len(daily_totals)

                annual_data.append({
                    'Year': year,
                    'Mean_Daily_Rainfall_mm': round(daily_mean, 2),
                    'Total_Annual_Rainfall_mm': round(annual_total, 2),
                    'Max_Daily_Rainfall_mm': round(max(daily_totals), 2),
                    'Min_Daily_Rainfall_mm': round(min(daily_totals), 2),
                    'Rainy_Days': rainy_days,
                    'Days_In_Year': len(daily_totals),
                    'Monthly_Average_mm': round(annual_total / 12, 2)
                })

                print(f"Processed: Mean={annual_data[-1]['Mean_Daily_Rainfall_mm']}mm/day, "
                      f"Total={annual_data[-1]['Total_Annual_Rainfall_mm']}mm/year, "
                      f"Rainy Days={annual_data[-1]['Rainy_Days']} out of {annual_data[-1]['Days_In_Year']} days")

        except Exception as e:
            print(f"Error processing {year}: {str(e)}")

    return pd.DataFrame(annual_data)

def analyze_monsoon_patterns(monthly_df):
    """Analyze monsoon rainfall patterns"""
    # Define monsoon months (June to September)
    monsoon_months = ['June', 'July', 'August', 'September']

    # Calculate monsoon season totals
    monthly_df['Is_Monsoon'] = monthly_df['Month_Name'].isin(monsoon_months)
    monsoon_stats = monthly_df[monthly_df['Is_Monsoon']].groupby('Year').agg({
        'Total_Monthly_Rainfall_mm': 'sum',
        'Rainy_Days': 'sum',
        'Random_Error_mm': 'mean'
    }).reset_index()

    monsoon_stats = monsoon_stats.rename(columns={
        'Total_Monthly_Rainfall_mm': 'Total_Monsoon_Rainfall_mm',
        'Rainy_Days': 'Monsoon_Rainy_Days',
        'Random_Error_mm': 'Mean_Monsoon_Error_mm'
    })

    return monsoon_stats

def export_rainfall_data():
    """Export rainfall data for Madhya Pradesh"""
    try:
        # Calculate and export monthly data
        print("\nProcessing monthly averages...")
        monthly_df = calculate_monthly_rainfall()
        monthly_output = 'mp_monthly_rainfall_data.csv'
        monthly_df.to_csv(monthly_output, index=False)
        print(f"Monthly data exported to {monthly_output}")
        print("\nMonthly data sample:")
        print(monthly_df.head())

        # Calculate and export annual data
        print("\nProcessing annual averages...")
        annual_df = calculate_annual_rainfall()
        annual_output = 'mp_annual_rainfall_data.csv'
        annual_df.to_csv(annual_output, index=False)
        print(f"Annual data exported to {annual_output}")
        print("\nAnnual data:")
        print(annual_df)

        # Calculate and export monsoon patterns
        print("\nAnalyzing monsoon patterns...")
        monsoon_df = analyze_monsoon_patterns(monthly_df)
        monsoon_output = 'mp_monsoon_rainfall_data.csv'
        monsoon_df.to_csv(monsoon_output, index=False)
        print(f"Monsoon data exported to {monsoon_output}")

        # Generate summary statistics
        print("\nMonthly Summary Statistics:")
        monthly_stats = monthly_df.groupby('Month_Name')['Total_Monthly_Rainfall_mm'] \
                                .agg(['mean', 'min', 'max', 'std']).round(2)
        print(monthly_stats)

        print("\nAnnual Summary Statistics:")
        annual_stats = annual_df['Total_Annual_Rainfall_mm'].agg(['mean', 'min', 'max', 'std']).round(2)
        print(annual_stats)

    except Exception as e:
        print(f"An error occurred: {str(e)}")
        print("Please check:")
        print("1. Earth Engine authentication is valid")
        print("2. Internet connection is stable")
        print("3. The specified region has available data")

if __name__ == "__main__":
    export_rainfall_data()
# Out:
# Processing monthly averages...
# Processing monthly data for January 2015...
# Processed: Mean=0.85mm/day, Total=26.35mm/month, Rainy Days=4 out of 31 days
# Processing monthly data for February 2015...
# Processed: Mean=0.29mm/day, Total=8.0mm/month, Rainy Days=0 out of 28 days
# Processing monthly data for March 2015...
# Processed: Mean=1.99mm/day, Total=61.73mm/month, Rainy Days=6 out of 31 days
# Processing monthly data for April 2015...
# Processed: Mean=0.26mm/day, Total=7.93mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for May 2015...
# Processed: Mean=0.35mm/day, Total=10.89mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for June 2015...
# Processed: Mean=3.38mm/day, Total=101.47mm/month, Rainy Days=9 out of 30 days
# Processing monthly data for July 2015...
# Processed: Mean=12.82mm/day, Total=397.46mm/month, Rainy Days=19 out of 31 days
# Processing monthly data for August 2015...
# Processed: Mean=7.39mm/day, Total=229.07mm/month, Rainy Days=16 out of 31 days
# Processing monthly data for September 2015...
# Processed: Mean=1.05mm/day, Total=31.64mm/month, Rainy Days=4 out of 30 days
# Processing monthly data for October 2015...
# Processed: Mean=0.61mm/day, Total=19.03mm/month, Rainy Days=3 out of 31 days
# Processing monthly data for November 2015...
# WARNING:googleapiclient.http:Sleeping 0.23 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-geosynta/value:compute?prettyPrint=false&alt=json, after 502
# Processed: Mean=0.09mm/day, Total=2.78mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2015...
# WARNING:googleapiclient.http:Sleeping 0.29 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-geosynta/value:compute?prettyPrint=false&alt=json, after 502
# Processed: Mean=0.01mm/day, Total=0.29mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for January 2016...
# Processed: Mean=0.55mm/day, Total=16.99mm/month, Rainy Days=2 out of 31 days
# Processing monthly data for February 2016...
# Processed: Mean=0.04mm/day, Total=1.14mm/month, Rainy Days=0 out of 29 days
# Processing monthly data for March 2016...
# Processed: Mean=0.28mm/day, Total=8.55mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for April 2016...
# Processed: Mean=0.03mm/day, Total=0.99mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for May 2016...
# Processed: Mean=0.17mm/day, Total=5.16mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for June 2016...
# Processed: Mean=2.45mm/day, Total=73.54mm/month, Rainy Days=6 out of 30 days
# Processing monthly data for July 2016...
# Processed: Mean=13.66mm/day, Total=423.48mm/month, Rainy Days=24 out of 31 days
# Processing monthly data for August 2016...
# Processed: Mean=13.55mm/day, Total=420.08mm/month, Rainy Days=24 out of 31 days
# Processing monthly data for September 2016...
# Processed: Mean=1.24mm/day, Total=37.18mm/month, Rainy Days=3 out of 30 days
# Processing monthly data for October 2016...
# Processed: Mean=0.15mm/day, Total=4.53mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for November 2016...
# Processed: Mean=0.04mm/day, Total=1.31mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2016...
# Processed: Mean=0.0mm/day, Total=0.04mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for January 2017...
# Processed: Mean=0.16mm/day, Total=4.93mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for February 2017...
# Processed: Mean=0.1mm/day, Total=2.68mm/month, Rainy Days=0 out of 28 days
# Processing monthly data for March 2017...
# Processed: Mean=0.06mm/day, Total=1.82mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for April 2017...
# Processed: Mean=0.0mm/day, Total=0.08mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for May 2017...
# Processed: Mean=0.26mm/day, Total=7.96mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for June 2017...
# Processed: Mean=2.33mm/day, Total=69.99mm/month, Rainy Days=8 out of 30 days
# Processing monthly data for July 2017...
# Processed: Mean=9.84mm/day, Total=305.09mm/month, Rainy Days=20 out of 31 days
# Processing monthly data for August 2017...
# Processed: Mean=2.98mm/day, Total=92.41mm/month, Rainy Days=13 out of 31 days
# Processing monthly data for September 2017...
# Processed: Mean=3.07mm/day, Total=92.0mm/month, Rainy Days=6 out of 30 days
# Processing monthly data for October 2017...
# Processed: Mean=0.1mm/day, Total=3.1mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for November 2017...
# Processed: Mean=0.01mm/day, Total=0.33mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2017...
# Processed: Mean=0.06mm/day, Total=1.97mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for January 2018...
# Processed: Mean=0.01mm/day, Total=0.22mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for February 2018...
# Processed: Mean=0.3mm/day, Total=8.42mm/month, Rainy Days=1 out of 28 days
# Processing monthly data for March 2018...
# Processed: Mean=0.1mm/day, Total=2.97mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for April 2018...
# Processed: Mean=0.15mm/day, Total=4.64mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for May 2018...
# Processed: Mean=0.15mm/day, Total=4.66mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for June 2018...
# Processed: Mean=1.75mm/day, Total=52.39mm/month, Rainy Days=7 out of 30 days
# Processing monthly data for July 2018...
# Processed: Mean=7.54mm/day, Total=233.77mm/month, Rainy Days=20 out of 31 days
# Processing monthly data for August 2018...
# Processed: Mean=6.45mm/day, Total=200.03mm/month, Rainy Days=21 out of 31 days
# Processing monthly data for September 2018...
# Processed: Mean=4.57mm/day, Total=137.25mm/month, Rainy Days=8 out of 30 days
# Processing monthly data for October 2018...
# Processed: Mean=0.04mm/day, Total=1.27mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for November 2018...
# Processed: Mean=0.0mm/day, Total=0.14mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2018...
# Processed: Mean=0.05mm/day, Total=1.7mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for January 2019...
# Processed: Mean=0.26mm/day, Total=8.08mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for February 2019...
# Processed: Mean=0.25mm/day, Total=7.13mm/month, Rainy Days=1 out of 28 days
# Processing monthly data for March 2019...
# Processed: Mean=0.27mm/day, Total=8.23mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for April 2019...
# Processed: Mean=0.28mm/day, Total=8.42mm/month, Rainy Days=2 out of 30 days
# Processing monthly data for May 2019...
# Processed: Mean=0.08mm/day, Total=2.54mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for June 2019...
# Processed: Mean=2.17mm/day, Total=64.99mm/month, Rainy Days=6 out of 30 days
# Processing monthly data for July 2019...
# Processed: Mean=10.41mm/day, Total=322.67mm/month, Rainy Days=19 out of 31 days
# Processing monthly data for August 2019...
# Processed: Mean=13.12mm/day, Total=406.86mm/month, Rainy Days=22 out of 31 days
# Processing monthly data for September 2019...
# Processed: Mean=10.11mm/day, Total=303.28mm/month, Rainy Days=22 out of 30 days
# Processing monthly data for October 2019...
# Processed: Mean=1.16mm/day, Total=36.05mm/month, Rainy Days=3 out of 31 days
# Processing monthly data for November 2019...
# Processed: Mean=0.16mm/day, Total=4.89mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2019...
# Processed: Mean=0.38mm/day, Total=11.7mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for January 2020...
# Processed: Mean=0.88mm/day, Total=27.27mm/month, Rainy Days=3 out of 31 days
# Processing monthly data for February 2020...
# Processed: Mean=0.08mm/day, Total=2.18mm/month, Rainy Days=0 out of 29 days
# Processing monthly data for March 2020...
# Processed: Mean=0.67mm/day, Total=20.65mm/month, Rainy Days=2 out of 31 days
# Processing monthly data for April 2020...
# Processed: Mean=0.39mm/day, Total=11.73mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for May 2020...
# Processed: Mean=0.39mm/day, Total=12.19mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for June 2020...
# Processed: Mean=4.97mm/day, Total=149.03mm/month, Rainy Days=15 out of 30 days
# Processing monthly data for July 2020...
# Processed: Mean=2.94mm/day, Total=91.2mm/month, Rainy Days=10 out of 31 days
# Processing monthly data for August 2020...
# Processed: Mean=14.84mm/day, Total=460.08mm/month, Rainy Days=24 out of 31 days
# Processing monthly data for September 2020...
# Processed: Mean=1.68mm/day, Total=50.53mm/month, Rainy Days=7 out of 30 days
# Processing monthly data for October 2020...
# Processed: Mean=0.25mm/day, Total=7.8mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for November 2020...
# Processed: Mean=0.09mm/day, Total=2.77mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2020...
# Processed: Mean=0.21mm/day, Total=6.61mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for January 2021...
# Processed: Mean=0.13mm/day, Total=4.05mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for February 2021...
# Processed: Mean=0.09mm/day, Total=2.4mm/month, Rainy Days=0 out of 28 days
# Processing monthly data for March 2021...
# Processed: Mean=0.14mm/day, Total=4.47mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for April 2021...
# Processed: Mean=0.02mm/day, Total=0.62mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for May 2021...
# Processed: Mean=1.56mm/day, Total=48.32mm/month, Rainy Days=6 out of 31 days
# Processing monthly data for June 2021...
# Processed: Mean=3.73mm/day, Total=111.85mm/month, Rainy Days=13 out of 30 days
# Processing monthly data for July 2021...
# Processed: Mean=7.03mm/day, Total=217.96mm/month, Rainy Days=17 out of 31 days
# Processing monthly data for August 2021...
# Processed: Mean=4.47mm/day, Total=138.63mm/month, Rainy Days=15 out of 31 days
# Processing monthly data for September 2021...
# Processed: Mean=4.63mm/day, Total=138.84mm/month, Rainy Days=11 out of 30 days
# Processing monthly data for October 2021...
# Processed: Mean=0.98mm/day, Total=30.25mm/month, Rainy Days=2 out of 31 days
# Processing monthly data for November 2021...
# Processed: Mean=0.13mm/day, Total=3.75mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2021...
# Processed: Mean=0.26mm/day, Total=8.21mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for January 2022...
# Processed: Mean=1.28mm/day, Total=39.54mm/month, Rainy Days=4 out of 31 days
# Processing monthly data for February 2022...
# Processed: Mean=0.04mm/day, Total=1.1mm/month, Rainy Days=0 out of 28 days
# Processing monthly data for March 2022...
# Processed: Mean=0.02mm/day, Total=0.71mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for April 2022...
# Processed: Mean=0.02mm/day, Total=0.58mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for May 2022...
# Processed: Mean=0.15mm/day, Total=4.75mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for June 2022...
# Processed: Mean=2.33mm/day, Total=69.8mm/month, Rainy Days=9 out of 30 days
# Processing monthly data for July 2022...
# Processed: Mean=9.32mm/day, Total=288.8mm/month, Rainy Days=23 out of 31 days
# Processing monthly data for August 2022...
# Processed: Mean=13.13mm/day, Total=407.13mm/month, Rainy Days=21 out of 31 days
# Processing monthly data for September 2022...
# Processed: Mean=5.62mm/day, Total=168.74mm/month, Rainy Days=12 out of 30 days
# Processing monthly data for October 2022...
# Processed: Mean=2.4mm/day, Total=74.44mm/month, Rainy Days=7 out of 31 days
# Processing monthly data for November 2022...
# Processed: Mean=0.0mm/day, Total=0.06mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2022...
# Processed: Mean=0.12mm/day, Total=3.68mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for January 2023...
# Processed: Mean=0.28mm/day, Total=8.68mm/month, Rainy Days=2 out of 31 days
# Processing monthly data for February 2023...
# Processed: Mean=0.0mm/day, Total=0.03mm/month, Rainy Days=0 out of 28 days
# Processing monthly data for March 2023...
# Processed: Mean=0.56mm/day, Total=17.44mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for April 2023...
# Processed: Mean=0.78mm/day, Total=23.55mm/month, Rainy Days=1 out of 30 days
# Processing monthly data for May 2023...
# Processed: Mean=0.5mm/day, Total=15.52mm/month, Rainy Days=2 out of 31 days
# Processing monthly data for June 2023...
# Processed: Mean=4.64mm/day, Total=139.22mm/month, Rainy Days=11 out of 30 days
# Processing monthly data for July 2023...
# Processed: Mean=7.11mm/day, Total=220.38mm/month, Rainy Days=22 out of 31 days
# Processing monthly data for August 2023...
# Processed: Mean=4.93mm/day, Total=152.86mm/month, Rainy Days=10 out of 31 days
# Processing monthly data for September 2023...
# Processed: Mean=7.53mm/day, Total=226.04mm/month, Rainy Days=13 out of 30 days
# Processing monthly data for October 2023...
# Processed: Mean=0.06mm/day, Total=1.8mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for November 2023...
# Processed: Mean=1.02mm/day, Total=30.74mm/month, Rainy Days=2 out of 30 days
# Processing monthly data for December 2023...
# Processed: Mean=0.26mm/day, Total=8.07mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for January 2024...
# Processed: Mean=0.27mm/day, Total=8.52mm/month, Rainy Days=0 out of 31 days
# Processing monthly data for February 2024...
# Processed: Mean=0.33mm/day, Total=9.62mm/month, Rainy Days=2 out of 29 days
# Processing monthly data for March 2024...
# Processed: Mean=0.34mm/day, Total=10.49mm/month, Rainy Days=2 out of 31 days
# Processing monthly data for April 2024...
# Processed: Mean=0.35mm/day, Total=10.52mm/month, Rainy Days=1 out of 30 days
# Processing monthly data for May 2024...
# Processed: Mean=0.32mm/day, Total=9.79mm/month, Rainy Days=2 out of 31 days
# Processing monthly data for June 2024...
# Processed: Mean=3.87mm/day, Total=116.07mm/month, Rainy Days=11 out of 30 days
# Processing monthly data for July 2024...
# Processed: Mean=5.51mm/day, Total=170.72mm/month, Rainy Days=14 out of 31 days
# Processing monthly data for August 2024...
# Processed: Mean=9.42mm/day, Total=292.07mm/month, Rainy Days=18 out of 31 days
# Processing monthly data for September 2024...
# Processed: Mean=4.55mm/day, Total=136.53mm/month, Rainy Days=11 out of 30 days
# Processing monthly data for October 2024...
# Processed: Mean=0.64mm/day, Total=19.91mm/month, Rainy Days=3 out of 31 days
# Processing monthly data for November 2024...
# Processed: Mean=0.0mm/day, Total=0.01mm/month, Rainy Days=0 out of 30 days
# Processing monthly data for December 2024...
# Processed: Mean=6.91mm/day, Total=214.23mm/month, Rainy Days=1 out of 31 days
# Processing monthly data for January 2025...
# Monthly data exported to mp_monthly_rainfall_data.csv
#
# Monthly data sample:
#    Year  Month Month_Name  Mean_Daily_Rainfall_mm  Total_Monthly_Rainfall_mm  \
# 0  2015      1    January                    0.85                      26.35
# 1  2015      2   February                    0.29                       8.00
# 2  2015      3      March                    1.99                      61.73
# 3  2015      4      April                    0.26                       7.93
# 4  2015      5        May                    0.35                      10.89
#
#    Max_Daily_Rainfall_mm  Min_Daily_Rainfall_mm  Rainy_Days  Days_In_Month
# 0                   5.13                    0.0           4             31
# 1                   1.79                    0.0           0             28
# 2                  18.08                    0.0           6             31
# 3                   2.25                    0.0           0             30
# 4                   4.80                    0.0           1             31
#
# Processing annual averages...
# Processing annual data for 2015...
# Processed: Mean=2.46mm/day, Total=896.64mm/year, Rainy Days=62 out of 365 days
# Processing annual data for 2016...
# Processed: Mean=2.71mm/day, Total=993.0mm/year, Rainy Days=60 out of 366 days
# Processing annual data for 2017...
# Processed: Mean=1.6mm/day, Total=582.36mm/year, Rainy Days=48 out of 365 days
# Processing annual data for 2018...
# Processed: Mean=1.77mm/day, Total=647.45mm/year, Rainy Days=58 out of 365 days
# Processing annual data for 2019...
# Processed: Mean=3.25mm/day, Total=1184.84mm/year, Rainy Days=78 out of 365 days
# Processing annual data for 2020...
# Processed: Mean=2.3mm/day, Total=842.04mm/year, Rainy Days=62 out of 366 days
# Processing annual data for 2021...
# Processed: Mean=1.94mm/day, Total=709.35mm/year, Rainy Days=65 out of 365 days
# Processing annual data for 2022...
# Processed: Mean=2.9mm/day, Total=1059.34mm/year, Rainy Days=76 out of 365 days
# Processing annual data for 2023...
# Processed: Mean=2.31mm/day, Total=844.33mm/year, Rainy Days=65 out of 365 days
# Processing annual data for 2024...
# Processed: Mean=2.73mm/day, Total=998.5mm/year, Rainy Days=65 out of 366 days
# Processing annual data for 2025...
# Annual data exported to mp_annual_rainfall_data.csv
#
# Annual data:
#    Year  Mean_Daily_Rainfall_mm  Total_Annual_Rainfall_mm  \
# 0  2015                    2.46                    896.64
# 1  2016                    2.71                    993.00
# 2  2017                    1.60                    582.36
# 3  2018                    1.77                    647.45
# 4  2019                    3.25                   1184.84
# 5  2020                    2.30                    842.04
# 6  2021                    1.94                    709.35
# 7  2022                    2.90                   1059.34
# 8  2023                    2.31                    844.33
# 9  2024                    2.73                    998.50
#
#    Max_Daily_Rainfall_mm  Min_Daily_Rainfall_mm  Rainy_Days  Days_In_Year  \
# 0                  52.60                      0          62           365
# 1                  55.57                      0          60           366
# 2                  36.80                      0          48           365
# 3                  34.83                      0          58           365
# 4                  61.22                      0          78           365
# 5                  61.66                      0          62           366
# 6                  48.45                      0          65           365
# 7                  61.45                      0          76           365
# 8                  58.60                      0          65           365
# 9                 212.87                      0          65           366
#
#    Monthly_Average_mm
# 0               74.72
# 1               82.75
# 2               48.53
# 3               53.95
# 4               98.74
# 5               70.17
# 6               59.11
# 7               88.28
# 8               70.36
# 9               83.21
#
# Analyzing monsoon patterns...
# An error occurred: "Column(s) ['Random_Error_mm'] do not exist"
# Please check:
# 1. Earth Engine authentication is valid
# 2. Internet connection is stable
# 3. The specified region has available data

# %% [markdown]
# ## Export Wind Speed

# %%
import ee
import pandas as pd
from datetime import datetime
import calendar
import numpy as np

# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project='ee-geosynta')

def get_mp_boundary():
    """Get Madhya Pradesh's administrative boundary"""
    states = ee.FeatureCollection('FAO/GAUL/2015/level1')
    mp = states.filter(ee.Filter.eq('ADM1_NAME', 'Madhya Pradesh')).geometry()
    return mp

def calculate_monthly_wind():
    """Calculate monthly wind statistics for Madhya Pradesh using ERA5 data"""
    # ERA5 provides u and v components of wind at 10m height
    era5 = ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY')
    roi = get_mp_boundary()

    current_year = datetime.now().year
    current_month = datetime.now().month

    monthly_data = []

    for year in range(2015, current_year + 1):
        for month in range(1, 13):
            if year == current_year and month > current_month:
                continue

            try:
                print(f"Processing monthly wind data for {calendar.month_name[month]} {year}...")

                start_date = ee.Date.fromYMD(year, month, 1)
                if month == 12:
                    end_date = ee.Date.fromYMD(year + 1, 1, 1)
                else:
                    end_date = ee.Date.fromYMD(year, month + 1, 1)

                # Get wind components
                collection = era5.filter(ee.Filter.date(start_date, end_date)) \
                               .select(['u_component_of_wind_10m', 'v_component_of_wind_10m'])

                # Get unique dates
                dates = collection.aggregate_array('system:time_start') \
                    .map(lambda t: ee.Date(t).format('YYYY-MM-dd')).distinct()
                dates_list = dates.getInfo()

                daily_speeds = []
                daily_directions = []

                for date in dates_list:
                    # Get all images for this date
                    day_images = collection.filter(
                        ee.Filter.eq('system:time_start', ee.Date.parse('YYYY-MM-dd', date).millis())
                    )

                    # Calculate daily mean wind components
                    daily_means = day_images.mean().reduceRegion(
                        reducer=ee.Reducer.mean(),
                        geometry=roi,
                        scale=11132,
                        maxPixels=1e9
                    ).getInfo()

                    # Extract u and v components
                    u = daily_means['u_component_of_wind_10m']
                    v = daily_means['v_component_of_wind_10m']

                    # Calculate wind speed and direction
                    speed = np.sqrt(u**2 + v**2)
                    direction = (270 - np.degrees(np.arctan2(v, u))) % 360  # Convert to meteorological convention

                    daily_speeds.append(speed)
                    daily_directions.append(direction)

                if daily_speeds:
                    # Calculate monthly statistics
                    mean_speed = np.mean(daily_speeds)
                    max_speed = np.max(daily_speeds)
                    min_speed = np.min(daily_speeds)

                    # Calculate prevailing wind direction (most common direction sector)
                    sectors = np.array([0, 45, 90, 135, 180, 225, 270, 315, 360])
                    digitized = np.digitize(daily_directions, sectors)
                    direction_counts = np.bincount(digitized)
                    prevailing_sector = sectors[np.argmax(direction_counts[1:])]  # Skip first bin

                    # Count high wind days (speed > 5 m/s)
                    high_wind_days = sum(1 for speed in daily_speeds if speed > 5)

                    monthly_data.append({
                        'Year': year,
                        'Month': month,
                        'Month_Name': calendar.month_name[month],
                        'Mean_Wind_Speed_ms': round(mean_speed, 2),
                        'Max_Wind_Speed_ms': round(max_speed, 2),
                        'Min_Wind_Speed_ms': round(min_speed, 2),
                        'Prevailing_Wind_Direction_deg': round(prevailing_sector),
                        'High_Wind_Days': high_wind_days,
                        'Days_In_Month': len(daily_speeds)
                    })

                    print(f"Processed: Mean Speed={monthly_data[-1]['Mean_Wind_Speed_ms']}m/s, "
                          f"Prevailing Direction={monthly_data[-1]['Prevailing_Wind_Direction_deg']}°, "
                          f"High Wind Days={monthly_data[-1]['High_Wind_Days']}")

            except Exception as e:
                print(f"Error processing {calendar.month_name[month]} {year}: {str(e)}")

    return pd.DataFrame(monthly_data)

def calculate_annual_wind():
    """Calculate annual wind statistics for Madhya Pradesh"""
    era5 = ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY')
    roi = get_mp_boundary()

    current_year = datetime.now().year
    annual_data = []

    for year in range(2015, current_year + 1):
        try:
            print(f"Processing annual wind data for {year}...")

            start_date = ee.Date.fromYMD(year, 1, 1)
            end_date = ee.Date.fromYMD(year + 1, 1, 1)

            # Get wind components
            collection = era5.filter(ee.Filter.date(start_date, end_date)) \
                           .select(['u_component_of_wind_10m', 'v_component_of_wind_10m'])

            # Get unique dates
            dates = collection.aggregate_array('system:time_start') \
                .map(lambda t: ee.Date(t).format('YYYY-MM-dd')).distinct()
            dates_list = dates.getInfo()

            daily_speeds = []
            daily_directions = []
            monthly_prevailing_directions = []

            for date in dates_list:
                # Get all images for this date
                day_images = collection.filter(
                    ee.Filter.eq('system:time_start', ee.Date.parse('YYYY-MM-dd', date).millis())
                )

                # Calculate daily mean wind components
                daily_means = day_images.mean().reduceRegion(
                    reducer=ee.Reducer.mean(),
                    geometry=roi,
                    scale=11132,
                    maxPixels=1e9
                ).getInfo()

                # Extract u and v components
                u = daily_means['u_component_of_wind_10m']
                v = daily_means['v_component_of_wind_10m']

                # Calculate wind speed and direction
                speed = np.sqrt(u**2 + v**2)
                direction = (270 - np.degrees(np.arctan2(v, u))) % 360

                daily_speeds.append(speed)
                daily_directions.append(direction)

            if daily_speeds:
                # Calculate annual statistics
                mean_speed = np.mean(daily_speeds)
                max_speed = np.max(daily_speeds)
                min_speed = np.min(daily_speeds)

                # Calculate annual prevailing wind direction
                sectors = np.array([0, 45, 90, 135, 180, 225, 270, 315, 360])
                digitized = np.digitize(daily_directions, sectors)
                direction_counts = np.bincount(digitized)
                prevailing_sector = sectors[np.argmax(direction_counts[1:])]

                # Count high wind days (speed > 5 m/s)
                high_wind_days = sum(1 for speed in daily_speeds if speed > 5)

                annual_data.append({
                    'Year': year,
                    'Mean_Wind_Speed_ms': round(mean_speed, 2),
                    'Max_Wind_Speed_ms': round(max_speed, 2),
                    'Min_Wind_Speed_ms': round(min_speed, 2),
                    'Prevailing_Wind_Direction_deg': round(prevailing_sector),
                    'High_Wind_Days': high_wind_days,
                    'Days_In_Year': len(daily_speeds),
                    'Monthly_Average_Speed_ms': round(mean_speed, 2)
                })

                print(f"Processed: Mean Speed={annual_data[-1]['Mean_Wind_Speed_ms']}m/s, "
                      f"Prevailing Direction={annual_data[-1]['Prevailing_Wind_Direction_deg']}°, "
                      f"High Wind Days={annual_data[-1]['High_Wind_Days']} out of {annual_data[-1]['Days_In_Year']} days")

        except Exception as e:
            print(f"Error processing {year}: {str(e)}")

    return pd.DataFrame(annual_data)

def export_wind_data():
    """Export wind data analysis"""
    try:
        # Calculate and export monthly data
        print("\nProcessing monthly wind averages...")
        monthly_df = calculate_monthly_wind()
        monthly_output = 'mp_monthly_wind_data.csv'
        monthly_df.to_csv(monthly_output, index=False)
        print(f"Monthly wind data exported to {monthly_output}")

        # Calculate and export annual data
        print("\nProcessing annual wind averages...")
        annual_df = calculate_annual_wind()
        annual_output = 'mp_annual_wind_data.csv'
        annual_df.to_csv(annual_output, index=False)
        print(f"Annual wind data exported to {annual_output}")

        # Generate summary statistics
        print("\nMonthly Wind Summary Statistics:")
        monthly_stats = monthly_df.groupby('Month_Name')['Mean_Wind_Speed_ms'].agg(['mean', 'min', 'max']).round(2)
        print(monthly_stats)

        print("\nAnnual Wind Summary Statistics:")
        annual_stats = annual_df['Mean_Wind_Speed_ms'].agg(['mean', 'min', 'max']).round(2)
        print(annual_stats)

    except Exception as e:
        print(f"An error occurred: {str(e)}")

if __name__ == "__main__":
    export_wind_data()
# Out:
# Processing monthly wind averages...
# Processing monthly wind data for January 2015...
# Processed: Mean Speed=1.2m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for February 2015...
# Processed: Mean Speed=1.21m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for March 2015...
# Processed: Mean Speed=1.01m/s, Prevailing Direction=90°, High Wind Days=0
# Processing monthly wind data for April 2015...
# Processed: Mean Speed=1.26m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for May 2015...
# Processed: Mean Speed=1.86m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2015...
# Processed: Mean Speed=2.03m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2015...
# Processed: Mean Speed=2.87m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2015...
# Processed: Mean Speed=2.06m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2015...
# Processed: Mean Speed=1.67m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for October 2015...
# Processed: Mean Speed=0.82m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for November 2015...
# Processed: Mean Speed=0.99m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for December 2015...
# Processed: Mean Speed=1.23m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for January 2016...
# Processed: Mean Speed=1.02m/s, Prevailing Direction=90°, High Wind Days=0
# Processing monthly wind data for February 2016...
# Processed: Mean Speed=1.42m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for March 2016...
# Processed: Mean Speed=1.02m/s, Prevailing Direction=90°, High Wind Days=0
# Processing monthly wind data for April 2016...
# Processed: Mean Speed=1.69m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for May 2016...
# Processed: Mean Speed=2.11m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2016...
# Processed: Mean Speed=1.83m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2016...
# Processed: Mean Speed=2.37m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2016...
# Processed: Mean Speed=2.12m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2016...
# Processed: Mean Speed=1.6m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for October 2016...
# Processed: Mean Speed=1.22m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for November 2016...
# Processed: Mean Speed=0.81m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for December 2016...
# Processed: Mean Speed=0.94m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for January 2017...
# Processed: Mean Speed=1.26m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for February 2017...
# Processed: Mean Speed=1.33m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for March 2017...
# Processed: Mean Speed=0.99m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for April 2017...
# Processed: Mean Speed=1.83m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for May 2017...
# Processed: Mean Speed=1.56m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2017...
# Processed: Mean Speed=2.18m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2017...
# Processed: Mean Speed=2.67m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2017...
# Processed: Mean Speed=2.27m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2017...
# Processed: Mean Speed=1.22m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for October 2017...
# Processed: Mean Speed=1.04m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for November 2017...
# Processed: Mean Speed=1.15m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for December 2017...
# Processed: Mean Speed=1.31m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for January 2018...
# Processed: Mean Speed=0.94m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for February 2018...
# Processed: Mean Speed=0.99m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for March 2018...
# Processed: Mean Speed=1.1m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for April 2018...
# Processed: Mean Speed=1.07m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for May 2018...
# Processed: Mean Speed=1.21m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2018...
# Processed: Mean Speed=2.5m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2018...
# Processed: Mean Speed=2.57m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2018...
# Processed: Mean Speed=2.6m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2018...
# Processed: Mean Speed=2.09m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for October 2018...
# Processed: Mean Speed=0.91m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for November 2018...
# Processed: Mean Speed=1.02m/s, Prevailing Direction=90°, High Wind Days=0
# Processing monthly wind data for December 2018...
# Processed: Mean Speed=1.2m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for January 2019...
# Processed: Mean Speed=1.28m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for February 2019...
# Processed: Mean Speed=1.33m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for March 2019...
# Processed: Mean Speed=1.26m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for April 2019...
# Processed: Mean Speed=0.91m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for May 2019...
# Processed: Mean Speed=1.78m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for June 2019...
# Processed: Mean Speed=1.99m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2019...
# Processed: Mean Speed=2.5m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2019...
# Processed: Mean Speed=2.07m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2019...
# Processed: Mean Speed=1.41m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for October 2019...
# Processed: Mean Speed=0.84m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for November 2019...
# Processed: Mean Speed=0.99m/s, Prevailing Direction=90°, High Wind Days=0
# Processing monthly wind data for December 2019...
# Processed: Mean Speed=1.34m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for January 2020...
# Processed: Mean Speed=1.22m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for February 2020...
# Processed: Mean Speed=1.34m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for March 2020...
# Processed: Mean Speed=1.07m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for April 2020...
# Processed: Mean Speed=1.02m/s, Prevailing Direction=90°, High Wind Days=0
# Processing monthly wind data for May 2020...
# Processed: Mean Speed=1.43m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2020...
# Processed: Mean Speed=1.94m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2020...
# Processed: Mean Speed=1.95m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2020...
# Processed: Mean Speed=2.23m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2020...
# Processed: Mean Speed=1.28m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for October 2020...
# Processed: Mean Speed=1.09m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for November 2020...
# Processed: Mean Speed=1.14m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for December 2020...
# Processed: Mean Speed=1.0m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for January 2021...
# Processed: Mean Speed=1.29m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for February 2021...
# Processed: Mean Speed=1.08m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for March 2021...
# Processed: Mean Speed=1.1m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for April 2021...
# Processed: Mean Speed=1.2m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for May 2021...
# Processed: Mean Speed=1.47m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2021...
# Processed: Mean Speed=2.41m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2021...
# Processed: Mean Speed=2.44m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2021...
# Processed: Mean Speed=2.32m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2021...
# Processed: Mean Speed=1.39m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for October 2021...
# Processed: Mean Speed=1.03m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for November 2021...
# Processed: Mean Speed=1.34m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for December 2021...
# Processed: Mean Speed=1.32m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for January 2022...
# Processed: Mean Speed=1.2m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for February 2022...
# Processed: Mean Speed=1.22m/s, Prevailing Direction=90°, High Wind Days=0
# Processing monthly wind data for March 2022...
# Processed: Mean Speed=1.1m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for April 2022...
# Processed: Mean Speed=1.43m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for May 2022...
# Processed: Mean Speed=1.96m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2022...
# Processed: Mean Speed=2.37m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2022...
# Processed: Mean Speed=1.46m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2022...
# Processed: Mean Speed=1.86m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for September 2022...
# Processed: Mean Speed=1.72m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for October 2022...
# Processed: Mean Speed=1.14m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for November 2022...
# Processed: Mean Speed=0.8m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for December 2022...
# Processed: Mean Speed=1.02m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for January 2023...
# Processed: Mean Speed=1.25m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for February 2023...
# Processed: Mean Speed=1.14m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for March 2023...
# Processed: Mean Speed=0.95m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for April 2023...
# Processed: Mean Speed=1.26m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for May 2023...
# Processed: Mean Speed=1.55m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2023...
# Processed: Mean Speed=2.4m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for July 2023...
# Processed: Mean Speed=1.86m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2023...
# Processed: Mean Speed=2.81m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2023...
# Processed: Mean Speed=1.49m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for October 2023...
# Processed: Mean Speed=1.11m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for November 2023...
# Processed: Mean Speed=1.19m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for December 2023...
# Processed: Mean Speed=1.24m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for January 2024...
# Processed: Mean Speed=1.25m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for February 2024...
# Processed: Mean Speed=1.4m/s, Prevailing Direction=0°, High Wind Days=0
# Processing monthly wind data for March 2024...
# Processed: Mean Speed=1.13m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for April 2024...
# Processed: Mean Speed=1.54m/s, Prevailing Direction=270°, High Wind Days=0
# Processing monthly wind data for May 2024...
# Processed: Mean Speed=1.66m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for June 2024...
# Processed: Mean Speed=2.33m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for July 2024...
# Processed: Mean Speed=2.05m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for August 2024...
# Processed: Mean Speed=1.93m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for September 2024...
# Processed: Mean Speed=1.58m/s, Prevailing Direction=225°, High Wind Days=0
# Processing monthly wind data for October 2024...
# Processed: Mean Speed=0.96m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for November 2024...
# Processed: Mean Speed=0.81m/s, Prevailing Direction=90°, High Wind Days=0
# Processing monthly wind data for December 2024...
# Processed: Mean Speed=1.23m/s, Prevailing Direction=45°, High Wind Days=0
# Processing monthly wind data for January 2025...
# Monthly wind data exported to mp_monthly_wind_data.csv
#
# Processing annual wind averages...
# Processing annual wind data for 2015...
# Processed: Mean Speed=1.52m/s, Prevailing Direction=225°, High Wind Days=0 out of 365 days
# Processing annual wind data for 2016...
# Processed: Mean Speed=1.51m/s, Prevailing Direction=225°, High Wind Days=0 out of 366 days
# Processing annual wind data for 2017...
# Processed: Mean Speed=1.57m/s, Prevailing Direction=225°, High Wind Days=0 out of 365 days
# Processing annual wind data for 2018...
# Processed: Mean Speed=1.52m/s, Prevailing Direction=225°, High Wind Days=0 out of 365 days
# Processing annual wind data for 2019...
# Processed: Mean Speed=1.48m/s, Prevailing Direction=225°, High Wind Days=0 out of 365 days
# Processing annual wind data for 2020...
# Processed: Mean Speed=1.39m/s, Prevailing Direction=225°, High Wind Days=0 out of 366 days
# Processing annual wind data for 2021...
# Processed: Mean Speed=1.54m/s, Prevailing Direction=225°, High Wind Days=0 out of 365 days
# Processing annual wind data for 2022...
# Processed: Mean Speed=1.44m/s, Prevailing Direction=225°, High Wind Days=0 out of 365 days
# Processing annual wind data for 2023...
# Processed: Mean Speed=1.52m/s, Prevailing Direction=225°, High Wind Days=0 out of 365 days
# Processing annual wind data for 2024...
# Processed: Mean Speed=1.49m/s, Prevailing Direction=225°, High Wind Days=0 out of 364 days
# Processing annual wind data for 2025...
# Annual wind data exported to mp_annual_wind_data.csv
#
# Monthly Wind Summary Statistics:
#             mean   min   max
# Month_Name
# April       1.32  0.91  1.83
# August      2.23  1.86  2.81
# December    1.18  0.94  1.34
# February    1.25  0.99  1.42
# January     1.19  0.94  1.29
# July        2.27  1.46  2.87
# June        2.20  1.83  2.50
# March       1.07  0.95  1.26
# May         1.66  1.21  2.11
# November    1.02  0.80  1.34
# October     1.02  0.82  1.22
# September   1.54  1.22  2.09
#
# Annual Wind Summary Statistics:
# mean    1.50
# min     1.39
# max     1.57
# Name: Mean_Wind_Speed_ms, dtype: float64

# %% [markdown]
# ## Export Solar Radiation

# %%
import ee
import pandas as pd
from datetime import datetime
import calendar
import numpy as np

# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project='ee-geosynta')

def get_mp_boundary():
    """Get Madhya Pradesh's administrative boundary"""
    states = ee.FeatureCollection('FAO/GAUL/2015/level1')
    mp = states.filter(ee.Filter.eq('ADM1_NAME', 'Madhya Pradesh')).geometry()
    return mp

def calculate_monthly_solar():
    """Calculate monthly solar radiation statistics for Madhya Pradesh using ERA5 data"""
    era5 = ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY')
    roi = get_mp_boundary()

    current_year = datetime.now().year
    current_month = datetime.now().month

    monthly_data = []

    # Solar radiation variables from ERA5-Land
    solar_vars = [
        'surface_solar_radiation_downwards',  # Total solar radiation
        'surface_direct_solar_radiation',     # Direct solar radiation
        'surface_net_solar_radiation'         # Net solar radiation
    ]

    for year in range(2015, current_year + 1):
        for month in range(1, 13):
            if year == current_year and month > current_month:
                continue

            try:
                print(f"Processing monthly solar data for {calendar.month_name[month]} {year}...")

                start_date = ee.Date.fromYMD(year, month, 1)
                if month == 12:
                    end_date = ee.Date.fromYMD(year + 1, 1, 1)
                else:
                    end_date = ee.Date.fromYMD(year, month + 1, 1)

                # Get solar radiation data
                collection = era5.filter(ee.Filter.date(start_date, end_date)) \
                               .select(solar_vars)

                # Get unique dates
                dates = collection.aggregate_array('system:time_start') \
                    .map(lambda t: ee.Date(t).format('YYYY-MM-dd')).distinct()
                dates_list = dates.getInfo()

                daily_total = []
                daily_direct = []
                daily_net = []
                sunny_days = 0  # Days with high solar radiation

                for date in dates_list:
                    # Get all images for this date
                    day_images = collection.filter(
                        ee.Filter.eq('system:time_start', ee.Date.parse('YYYY-MM-dd', date).millis())
                    )

                    # Calculate daily accumulated radiation
                    daily_sums = day_images.sum().reduceRegion(
                        reducer=ee.Reducer.mean(),
                        geometry=roi,
                        scale=11132,
                        maxPixels=1e9
                    ).getInfo()

                    # Convert from J/m² to kWh/m²/day (divide by 3.6e6)
                    total_rad = daily_sums['surface_solar_radiation_downwards'] / 3.6e6
                    direct_rad = daily_sums['surface_direct_solar_radiation'] / 3.6e6
                    net_rad = daily_sums['surface_net_solar_radiation'] / 3.6e6

                    daily_total.append(total_rad)
                    daily_direct.append(direct_rad)
                    daily_net.append(net_rad)

                    # Count sunny days (total radiation > 5 kWh/m²/day)
                    if total_rad > 5:
                        sunny_days += 1

                if daily_total:
                    # Calculate monthly statistics
                    monthly_data.append({
                        'Year': year,
                        'Month': month,
                        'Month_Name': calendar.month_name[month],
                        'Mean_Daily_Total_Radiation_kWh_m2': round(np.mean(daily_total), 2),
                        'Max_Daily_Total_Radiation_kWh_m2': round(np.max(daily_total), 2),
                        'Min_Daily_Total_Radiation_kWh_m2': round(np.min(daily_total), 2),
                        'Mean_Daily_Direct_Radiation_kWh_m2': round(np.mean(daily_direct), 2),
                        'Mean_Daily_Net_Radiation_kWh_m2': round(np.mean(daily_net), 2),
                        'Monthly_Total_Radiation_kWh_m2': round(sum(daily_total), 2),
                        'Sunny_Days': sunny_days,
                        'Days_In_Month': len(daily_total)
                    })

                    print(f"Processed: Mean Total={monthly_data[-1]['Mean_Daily_Total_Radiation_kWh_m2']}kWh/m²/day, "
                          f"Monthly Total={monthly_data[-1]['Monthly_Total_Radiation_kWh_m2']}kWh/m², "
                          f"Sunny Days={monthly_data[-1]['Sunny_Days']}")

            except Exception as e:
                print(f"Error processing {calendar.month_name[month]} {year}: {str(e)}")

    return pd.DataFrame(monthly_data)

def calculate_annual_solar():
    """Calculate annual solar radiation statistics for Madhya Pradesh"""
    era5 = ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY')
    roi = get_mp_boundary()

    current_year = datetime.now().year
    annual_data = []

    solar_vars = [
        'surface_solar_radiation_downwards',
        'surface_direct_solar_radiation',
        'surface_net_solar_radiation'
    ]

    for year in range(2015, current_year + 1):
        try:
            print(f"Processing annual solar data for {year}...")

            start_date = ee.Date.fromYMD(year, 1, 1)
            end_date = ee.Date.fromYMD(year + 1, 1, 1)

            # Get solar radiation data
            collection = era5.filter(ee.Filter.date(start_date, end_date)) \
                           .select(solar_vars)

            # Get unique dates
            dates = collection.aggregate_array('system:time_start') \
                .map(lambda t: ee.Date(t).format('YYYY-MM-dd')).distinct()
            dates_list = dates.getInfo()

            daily_total = []
            daily_direct = []
            daily_net = []
            sunny_days = 0

            for date in dates_list:
                # Get all images for this date
                day_images = collection.filter(
                    ee.Filter.eq('system:time_start', ee.Date.parse('YYYY-MM-dd', date).millis())
                )

                # Calculate daily accumulated radiation
                daily_sums = day_images.sum().reduceRegion(
                    reducer=ee.Reducer.mean(),
                    geometry=roi,
                    scale=11132,
                    maxPixels=1e9
                ).getInfo()

                # Convert from J/m² to kWh/m²/day
                total_rad = daily_sums['surface_solar_radiation_downwards'] / 3.6e6
                direct_rad = daily_sums['surface_direct_solar_radiation'] / 3.6e6
                net_rad = daily_sums['surface_net_solar_radiation'] / 3.6e6

                daily_total.append(total_rad)
                daily_direct.append(direct_rad)
                daily_net.append(net_rad)

                # Count sunny days
                if total_rad > 5:
                    sunny_days += 1

            if daily_total:
                # Calculate annual statistics
                annual_data.append({
                    'Year': year,
                    'Mean_Daily_Total_Radiation_kWh_m2': round(np.mean(daily_total), 2),
                    'Max_Daily_Total_Radiation_kWh_m2': round(np.max(daily_total), 2),
                    'Min_Daily_Total_Radiation_kWh_m2': round(np.min(daily_total), 2),
                    'Mean_Daily_Direct_Radiation_kWh_m2': round(np.mean(daily_direct), 2),
                    'Mean_Daily_Net_Radiation_kWh_m2': round(np.mean(daily_net), 2),
                    'Annual_Total_Radiation_kWh_m2': round(sum(daily_total), 2),
                    'Sunny_Days': sunny_days,
                    'Days_In_Year': len(daily_total),
                    'Monthly_Average_Radiation_kWh_m2': round(sum(daily_total)/12, 2)
                })

                print(f"Processed: Mean Total={annual_data[-1]['Mean_Daily_Total_Radiation_kWh_m2']}kWh/m²/day, "
                      f"Annual Total={annual_data[-1]['Annual_Total_Radiation_kWh_m2']}kWh/m², "
                      f"Sunny Days={annual_data[-1]['Sunny_Days']}")

        except Exception as e:
            print(f"Error processing {year}: {str(e)}")

    return pd.DataFrame(annual_data)

def export_solar_data():
    """Export solar radiation analysis data"""
    try:
        # Calculate and export monthly data
        print("\nProcessing monthly solar averages...")
        monthly_df = calculate_monthly_solar()
        monthly_output = 'mp_monthly_solar_data.csv'
        monthly_df.to_csv(monthly_output, index=False)
        print(f"Monthly solar data exported to {monthly_output}")

        # Calculate and export annual data
        print("\nProcessing annual solar averages...")
        annual_df = calculate_annual_solar()
        annual_output = 'mp_annual_solar_data.csv'
        annual_df.to_csv(annual_output, index=False)
        print(f"Annual solar data exported to {annual_output}")

        # Generate summary statistics
        print("\nMonthly Solar Radiation Summary Statistics:")
        monthly_stats = monthly_df.groupby('Month_Name')['Mean_Daily_Total_Radiation_kWh_m2'] \
                                .agg(['mean', 'min', 'max']).round(2)
        print(monthly_stats)

        print("\nAnnual Solar Radiation Summary Statistics:")
        annual_stats = annual_df['Mean_Daily_Total_Radiation_kWh_m2'].agg(['mean', 'min', 'max']).round(2)
        print(annual_stats)

    except Exception as e:
        print(f"An error occurred: {str(e)}")

if __name__ == "__main__":
    export_solar_data()
